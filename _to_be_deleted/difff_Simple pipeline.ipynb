# %%
import imports as i
import functions as f
import preprocessing as pp

# %%
PATH = {}
PATH["dataset_classification"] = "dataset/classification/"
PATH["dataset_labeling"] = "dataset/seq_labeling/"
PATH["music_reviews_train"] = PATH["dataset_classification"] + "music_reviews_train.json.gz"
PATH["music_reviews_dev"] = PATH["dataset_classification"] + "music_reviews_dev.json.gz"
PATH["music_reviews_test"] = PATH["dataset_classification"] + "music_reviews_test_masked.json.gz"
train = f.readJson(PATH["music_reviews_train"])
# Out:
# Number of data:  100000

# %%
X_train, y_train, train_idx, train_missing_idx = f.json_divide(train)

# %%
pipeline = i.Pipeline([
    ('remove_stop_words', pp.remove_stop_words()),
])

pipeline.fit_transform(X_train)
# Out:
# [['So',
#   'creative',
#   '!',
#   'Love',
#   'music',
#   'words',
#   'message',
#   '!',
#   'Some',
#   'favorite',
#   'songs',
#   'CD',
#   '.',
#   'I',
#   'bought',
#   'years',
#   'ago',
#   '!'],
#  ['This',
#   'tape',
#   'hardly',
#   'understood',
#   'listed',
#   'sale',
#   'good',
#   '.',
#   'It',
#   'VERY',
#   'BAD',
#   '.'],
#  ['Buy',
#   'CD',
#   '.',
#   'Do',
#   'buy',
#   'MP',
#   'album',
#   '.',
#   'Download',
#   'longer',
#   'available',
#   '.',
#   'But',
#   'find',
#   'purchased',
#   '.'],
#  ['I',
#   'love',
#   'Dallas',
#   'Holms',
#   'music',
#   'voice',
#   '!',
#   'Thank',
#   'You',
#   '!',
#   'I',
#   'attending',
#   'concerts',
#   'heaven',
#   'forever',
#   '!'],
#  ['Great', 'memories', 'early', 'years', 'Christ'],
#  ['I',
#   'listening',
#   'album',
#   'set',
#   'ENTIRE',
#   'life',
#   'years',
#   '!',
#   'I',
#   'remember',
#   'hearing',
#   'CD',
#   'repeat',
#   'every',
#   'night',
#   'toddler',
#   'brought',
#   'comfort',
#   'sleep',
#   'I',
#   'always',
#   'music',
#   'fan',
#   'rest',
#   '.',
#   'Well',
#   'worth',
#   'relaxation',
#   '!'],
#  ['I', 'love', 'music', '!', '!'],
#  ['Love',
#   'Talbot',
#   'music',
#   'inspiring',
#   'since',
#   'gift',
#   'I',
#   'buy',
#   'soon',
#   '.'],
#  ['Most',
#   'unique',
#   'sound',
#   '.',
#   'Nothing',
#   'even',
#   'similar',
#   'among',
#   'praise',
#   'music',
#   'choices',
#   '.',
#   'Truly',
#   'real',
#   'worshipful',
#   '.',
#   'I',
#   'referring',
#   'older',
#   'The',
#   'Lords',
#   'supper',
#   'part',
#   'extending',
#   'track',
#   '.'],
#  ['The',
#   'item',
#   'ordered',
#   'arrived',
#   'timely',
#   'manner',
#   '.',
#   'I',
#   'quite',
#   'impressed',
#   '.',
#   'The',
#   'quality',
#   'cd',
#   'music',
#   'fantastic',
#   '.',
#   'I',
#   'satisfied',
#   '.'],
#  ['If',
#   'preferences',
#   'religious',
#   'music',
#   'fall',
#   'half',
#   'way',
#   'old',
#   'church',
#   'chants',
#   'modern',
#   'praise',
#   'music',
#   'artist',
#   'listen',
#   '.'],
#  ['I',
#   'first',
#   'heard',
#   'The',
#   'Lord',
#   'Supper',
#   'vinyl',
#   'back',
#   'trying',
#   'get',
#   'copy',
#   'ever',
#   'since',
#   'come',
#   'conclusion',
#   'print',
#   'thrilled',
#   'find',
#   'CD',
#   'still',
#   'available',
#   'Amazon',
#   '.',
#   'Although',
#   'recorded',
#   'late',
#   'lyric',
#   'taken',
#   'liturgies',
#   'dating',
#   'back',
#   'several',
#   'centuries',
#   'even',
#   'today',
#   'album',
#   'still',
#   'wonderful',
#   'ability',
#   'move',
#   'one',
#   'deeply',
#   'profoundly',
#   'recording',
#   'wonderful',
#   'flow',
#   'track',
#   'track',
#   'almost',
#   'making',
#   'concept',
#   'album',
#   'needing',
#   'listened',
#   'start',
#   'finish',
#   'many',
#   'best',
#   'John',
#   'Michael',
#   'Talbot',
#   'track',
#   'taken',
#   'original',
#   'Lord',
#   'Supper',
#   'wonderful',
#   'album',
#   'works',
#   'best',
#   'whole',
#   '.',
#   'If',
#   'looking',
#   'swept',
#   'away',
#   'music',
#   'lyrics',
#   'profound',
#   'orchestral',
#   'arrangement',
#   'superb',
#   'guitar',
#   'choir',
#   'obviously',
#   'thrilled',
#   'apart',
#   'project',
#   'I',
#   'sincerely',
#   'recommend',
#   'getting',
#   'album',
#   '.',
#   'John',
#   'Michael',
#   'Talbot',
#   'able',
#   'weave',
#   'complex',
#   'lyrics',
#   'truly',
#   'beautiful',
#   'melodies',
#   'voice',
#   'full',
#   'honest',
#   'conviction',
#   'remarkably',
#   'inspiring',
#   '.',
#   'The',
#   'Lord',
#   'Supper',
#   'one',
#   'best',
#   'every',
#   'track',
#   'consecutively',
#   'moving',
#   'listener',
#   'closer',
#   'experience',
#   'Lords',
#   'Supper',
#   'best',
#   'albums',
#   'huge',
#   'bonus',
#   'Sparrow',
#   'also',
#   'included',
#   'album',
#   'Be',
#   'Exalted',
#   'CD',
#   'filled',
#   'old',
#   'favorites',
#   'also',
#   'treat',
#   'listen',
#   'although',
#   'coherent',
#   'Lord',
#   'Supper',
#   'still',
#   'wonderful',
#   '.',
#   'As',
#   'I',
#   'said',
#   'years',
#   'since',
#   'I',
#   'listened',
#   'album',
#   'although',
#   'something',
#   'years',
#   'putting',
#   'CD',
#   'swept',
#   'away',
#   'wonderful',
#   'today',
#   'I',
#   'first',
#   'heard',
#   '.'],
#  ['This',
#   'CD',
#   'contains',
#   'two',
#   'John',
#   'Michael',
#   'Talbot',
#   'earliest',
#   'releases',
#   'The',
#   'Lord',
#   'Supper',
#   'third',
#   'Christian',
#   'album',
#   'first',
#   'Catholic',
#   'Be',
#   'Exalted',
#   'fifteenth',
#   'released',
#   '.',
#   'Containing',
#   'tracks',
#   'compilation',
#   'Catholic',
#   'worship',
#   'praise',
#   'music',
#   'contains',
#   'many',
#   'essential',
#   'Talbot',
#   'songs',
#   'made',
#   'name',
#   'John',
#   'Michael',
#   'Talbot',
#   'household',
#   'word',
#   'Catholic',
#   'homes',
#   '.',
#   'The',
#   'Lord',
#   'Supper',
#   'probably',
#   'still',
#   'signature',
#   'release',
#   'minds',
#   'fans',
#   '.',
#   'Essential',
#   'JMT',
#   '!'],
#  ['Some',
#   'may',
#   'give',
#   'two',
#   'cd',
#   'set',
#   'five',
#   'stars',
#   'overtures',
#   'songs',
#   'stray',
#   'far',
#   'particular',
#   'taste',
#   'music',
#   '.',
#   'But',
#   'quiet',
#   'songs',
#   'good',
#   'musically',
#   'ears',
#   'rock',
#   'n',
#   'roll',
#   'lover',
#   '.',
#   'And',
#   'others',
#   'impressive',
#   'Card',
#   'ability',
#   'get',
#   'across',
#   'heart',
#   'felt',
#   'theological',
#   'thought',
#   'winning',
#   'alignment',
#   'words',
#   '.',
#   'One',
#   'albums',
#   'I',
#   'could',
#   'listen',
#   'solely',
#   'words',
#   '.',
#   'I',
#   'also',
#   'recommend',
#   'Present',
#   'Reality',
#   'era',
#   'stunning',
#   'mix',
#   'quiet',
#   'music',
#   'meaningful',
#   'words',
#   '.',
#   'I',
#   'haven',
#   'listened',
#   'recent',
#   'cds',
#   'greatest',
#   'hits',
#   'package',
#   'fine',
#   'well',
#   '.'],
#  ['I',
#   've',
#   'always',
#   'loved',
#   'album',
#   'I',
#   'could',
#   'never',
#   'afford',
#   '.',
#   'Michael',
#   'Card',
#   'always',
#   'one',
#   'favorite',
#   'Christian',
#   'artist',
#   '.'],
#  ['brings', 'back', 'good', 'ol', 'days', '!'],
#  ['Love',
#   'Dallas',
#   'Holm',
#   '!',
#   '!',
#   'His',
#   'songs',
#   'truly',
#   'inspiring',
#   '!',
#   'The',
#   'cd',
#   'great',
#   'scratches',
#   '.',
#   'U',
#   'feel',
#   'love',
#   'Dallas',
#   'Holm',
#   'God',
#   '.',
#   'Gives',
#   'us',
#   'hope',
#   'strength',
#   '!',
#   '!'],
#  ['These',
#   'may',
#   'America',
#   'Greatest',
#   'Old',
#   'time',
#   'Gospel',
#   'songs',
#   'way',
#   'presented',
#   'abomination',
#   '!',
#   'Gospel',
#   'especially',
#   'Old',
#   'Time',
#   'Gospel',
#   'music',
#   'soul',
#   'sung',
#   'heart',
#   '.',
#   'Neither',
#   'heart',
#   'soul',
#   'found',
#   'arrangements',
#   '.',
#   'I',
#   'would',
#   'compare',
#   'redition',
#   'classics',
#   'fast',
#   'food',
#   'wouldn',
#   'really',
#   'fair',
#   'since',
#   'fast',
#   'food',
#   'nutritional',
#   'value',
#   '.',
#   'I',
#   'found',
#   'music',
#   'plastic',
#   'CD',
#   'burned',
#   'nutritional',
#   'value',
#   'heart',
#   'soul',
#   'whatsoever',
#   '.',
#   'It',
#   'doesn',
#   'even',
#   'deserve',
#   'one',
#   'star',
#   '.'],
#  ['Few',
#   'turn',
#   'Scripture',
#   'song',
#   'well',
#   'Michael',
#   'Card',
#   '.',
#   'His',
#   'lyrics',
#   'cover',
#   'every',
#   'book',
#   'Bible',
#   'new',
#   'CD',
#   'focuses',
#   'gospel',
#   'Luke',
#   '.',
#   'This',
#   'collection',
#   'associated',
#   'Luke',
#   'The',
#   'Gospel',
#   'Amazement',
#   'first',
#   'four',
#   'commentaries',
#   'gospels',
#   'Card',
#   'Biblical',
#   'Imagination',
#   'Series',
#   '.',
#   'A',
#   'commentary',
#   'CD',
#   'remaining',
#   'gospels',
#   'released',
#   'next',
#   'three',
#   'years',
#   '.',
#   'Card',
#   'currently',
#   'hosting',
#   'Biblical',
#   'Imagination',
#   'seminars',
#   'across',
#   'country',
#   'teaching',
#   'engage',
#   'Scripture',
#   'level',
#   'informed',
#   'imagination',
#   '.',
#   'Judging',
#   'quality',
#   'commentary',
#   'response',
#   'receiving',
#   'seminars',
#   'events',
#   'worth',
#   'attending',
#   '.',
#   'Those',
#   'know',
#   'Card',
#   'music',
#   'recognize',
#   'always',
#   'informed',
#   'Scriptures',
#   'release',
#   'new',
#   'commentary',
#   'apparent',
#   'scholar',
#   'mentored',
#   'late',
#   'William',
#   'Lane',
#   '.',
#   'His',
#   'exposition',
#   'Luke',
#   'provides',
#   'basis',
#   'songs',
#   'cover',
#   'life',
#   'Christ',
#   'beginning',
#   'end',
#   '.',
#   'For',
#   'appreciate',
#   'nativity',
#   'songs',
#   'three',
#   'cover',
#   'Magnificant',
#   'What',
#   'Sort',
#   'Song',
#   '?',
#   'Christ',
#   'birth',
#   'A',
#   'King',
#   'Cattle',
#   'Trough',
#   'His',
#   'dedication',
#   'temple',
#   'Simeon',
#   'Song',
#   '.',
#   'Jeff',
#   'Taylor',
#   'gentle',
#   'accordion',
#   'beautifully',
#   'ties',
#   'three',
#   'together',
#   '.',
#   'Acoustic',
#   'guitar',
#   'piano',
#   'predominate',
#   'making',
#   'mellower',
#   'folk',
#   'oriented',
#   'offering',
#   'earlier',
#   'releases',
#   'pop',
#   'rock',
#   'influences',
#   '.',
#   'It',
#   'relaxed',
#   'mature',
#   'inspiring',
#   '.',
#   'He',
#   'employs',
#   'banjo',
#   'uilleann',
#   'pipes',
#   'instrumental',
#   'A',
#   'Little',
#   'Boy',
#   'Lost',
#   'last',
#   'song',
#   'Seven',
#   'Endless',
#   'Miles',
#   '.',
#   'His',
#   'banjo',
#   'playing',
#   'fast',
#   'steady',
#   'strong',
#   'interplay',
#   'pipes',
#   'delight',
#   '.',
#   'It',
#   'gives',
#   'songs',
#   'Celtic',
#   'feel',
#   '.',
#   'The',
#   'Pain',
#   'Persistence',
#   'Doubt',
#   'set',
#   'crucifixion',
#   'resurrection',
#   'piano',
#   'strings',
#   'mournful',
#   '.',
#   'It',
#   'captures',
#   'mood',
#   'melancholy',
#   'since',
#   'Christ',
#   'followers',
#   'expecting',
#   'rise',
#   '.',
#   'The',
#   'somber',
#   'tone',
#   'beauty',
#   '.',
#   'Community',
#   'important',
#   'Michael',
#   'Card',
#   '.',
#   'He',
#   'sees',
#   'creative',
#   'muse',
#   'springing',
#   'collaboration',
#   'rather',
#   'solitude',
#   '.',
#   'Three',
#   'four',
#   'children',
#   'contribute',
#   'along',
#   'Matthew',
#   'Ward',
#   'nd',
#   'Chapter',
#   'Acts',
#   'Kirk',
#   'Whalum',
#   'Scott',
#   'Roley',
#   'others',
#   '.',
#   'Matthew',
#   'Ward',
#   'Kirk',
#   'Whalum',
#   'saxophone',
#   'featured',
#   'opening',
#   'standout',
#   'track',
#   'A',
#   'World',
#   'Turned',
#   'Upside',
#   'Down',
#   'Ward',
#   'also',
#   'sings',
#   'A',
#   'Breath',
#   'Prayer',
#   'combination',
#   'Jesus',
#   'Prayer',
#   'Lord',
#   'Prayer',
#   '.',
#   'Matthew',
#   'Ward',
#   'contribution',
#   'drew',
#   'release',
#   'though',
#   'Card',
#   'singing',
#   'many',
#   'years',
#   'voices',
#   'remain',
#   'strong',
#   '.',
#   'On',
#   'Freedom',
#   'Card',
#   'starts',
#   'singing',
#   'I',
#   'lost',
#   'I',
#   'bound',
#   'And',
#   'I',
#   'captive',
#   'shame',
#   'keeps',
#   'holding',
#   '.',
#   'With',
#   'piano',
#   'strings',
#   'vocals',
#   'succeeds',
#   'capturing',
#   'heart',
#   'cry',
#   'free',
#   'burden',
#   'sin',
#   '.',
#   'I',
#   'also',
#   'appreciate',
#   'continually',
#   'points',
#   'Christ',
#   'answer',
#   '.',
#   'He',
#   'freedom',
#   '.',
#   'He',
#   'bread',
#   'wine',
#   '.',
#   'Card',
#   'doesn',
#   'get',
#   'better',
#   '.',
#   'Each',
#   'recordings',
#   'gem',
#   'like',
#   'resonates',
#   'deeply',
#   '.',
#   'Ironically',
#   'song',
#   'directly',
#   'tied',
#   'passage',
#   'Luke',
#   '.',
#   'Perhaps',
#   'says',
#   'something',
#   'challenge',
#   'adapting',
#   'scripture',
#   'song',
#   'make',
#   'sound',
#   'wooden',
#   '.',
#   'More',
#   'likely',
#   'Freedom',
#   'favorite',
#   'lyrics',
#   'personal',
#   'vulnerable',
#   'making',
#   'highly',
#   'relatable',
#   'us',
#   'feel',
#   'burden',
#   'human',
#   'broken',
#   'world',
#   '.',
#   'I',
#   'welcome',
#   'scripture',
#   'songs',
#   'like',
#   'ones',
#   'found',
#   'truth',
#   'life',
#   'contain',
#   '.',
#   'It',
#   'hard',
#   'appreciate',
#   'artful',
#   'Michael',
#   'Card',
#   'texts',
#   '.',
#   'Best',
#   'fashions',
#   'way',
#   'point',
#   'Christ',
#   '.',
#   'He',
#   'way',
#   'truth',
#   'life',
#   '.'],
#  ['If',
#   'seeking',
#   'recording',
#   'bring',
#   'actual',
#   'Essence',
#   'Runes',
#   'culture',
#   'discovered',
#   '.',
#   'Live',
#   'breath',
#   'feel',
#   'power',
#   'Odin',
#   'Runes',
#   'chanted',
#   'around',
#   '.',
#   'These',
#   'recordings',
#   'show',
#   'Runes',
#   'written',
#   'word',
#   'ever',
#   'could',
#   'used',
#   'raise',
#   'vibration',
#   'match',
#   'Shamans',
#   '.'],
#  ['This',
#   'live',
#   'recording',
#   'youth',
#   'Taize',
#   'meets',
#   'stringent',
#   'requirements',
#   'beauty',
#   'reverence',
#   'sophisticated',
#   'music',
#   '.',
#   'I',
#   'MA',
#   'theology',
#   'embodies',
#   'best',
#   'liberal',
#   'catholic',
#   'ecumenical',
#   'tradition',
#   '.',
#   'It',
#   'perfect',
#   'private',
#   'listening',
#   'simpler',
#   'pieces',
#   'utilized',
#   'catholic',
#   'protestant',
#   'liturgy',
#   '.'],
#  ['I',
#   'm',
#   'SAT',
#   'tutor',
#   'stand',
#   'listen',
#   'Ms',
#   '.',
#   'Mazer',
#   'annoying',
#   'voice',
#   'stories',
#   'dating',
#   'days',
#   'learn',
#   'new',
#   'words',
#   'approach',
#   'effective',
#   '.',
#   'For',
#   'teenagers',
#   'Ms',
#   '.',
#   'Mazer',
#   'much',
#   'listen',
#   'son',
#   'refuses',
#   '.',
#   'However',
#   'I',
#   've',
#   'listened',
#   'CD',
#   'I',
#   've',
#   'learned',
#   'remembered',
#   'new',
#   'words',
#   '.',
#   'I',
#   'would',
#   'suggest',
#   'borrow',
#   'one',
#   'CD',
#   'friend',
#   'try',
#   'first',
#   'buy',
#   '.',
#   'Ms',
#   '.',
#   'Mazer',
#   'approach',
#   'effective',
#   'Princeton',
#   'Reviews',
#   'Word',
#   'Smart',
#   'Word',
#   'Smart',
#   'II',
#   'tolerate',
#   '.',
#   'If',
#   'parent',
#   'doesn',
#   'allow',
#   'children',
#   'watch',
#   'Simpsons',
#   'South',
#   'Park',
#   'find',
#   'Ms',
#   '.',
#   'Mazar',
#   'stories',
#   'equally',
#   'crude',
#   '.',
#   'But',
#   'remember',
#   'targeted',
#   'year',
#   'old',
#   'students',
#   'probably',
#   'won',
#   'like',
#   'stories',
#   'doesn',
#   'say',
#   'anything',
#   'kids',
#   'already',
#   'hear',
#   'public',
#   'high',
#   'school',
#   '.'],
#  ['Well',
#   'would',
#   'certainly',
#   'expand',
#   'vocabulary',
#   '.',
#   'Normally',
#   'one',
#   'would',
#   'associate',
#   'idea',
#   'increasing',
#   'vocabulary',
#   'lifting',
#   'higher',
#   'level',
#   'communication',
#   'level',
#   'bit',
#   'dignified',
#   '.',
#   'If',
#   'never',
#   'want',
#   'associate',
#   'successful',
#   'people',
#   'world',
#   'want',
#   'know',
#   'taking',
#   'probably',
#   'CD',
#   '.',
#   'Or',
#   'high',
#   'school',
#   'run',
#   'away',
#   'hormones',
#   'want',
#   'impress',
#   'friends',
#   'bathroom',
#   'go',
#   '.',
#   'In',
#   'first',
#   'minutes',
#   'll',
#   'learn',
#   'word',
#   'abash',
#   'association',
#   'phrases',
#   'like',
#   'fly',
#   'open',
#   'people',
#   'see',
#   'private',
#   'parts',
#   '.',
#   'After',
#   'll',
#   'examples',
#   'help',
#   'learn',
#   'words',
#   'examples',
#   'things',
#   'like',
#   'woman',
#   'posting',
#   'nude',
#   'photos',
#   'weight',
#   'husband',
#   'internet',
#   '.',
#   'That',
#   'first',
#   'minutes',
#   '.',
#   'The',
#   'slang',
#   'used',
#   'examples',
#   'supports',
#   'idea',
#   'CD',
#   'someone',
#   'vocabularly',
#   'like',
#   'totally',
#   'cool',
#   '.',
#   'Buy',
#   'dictionary',
#   '.'],
#  ['I',
#   'agree',
#   'reviewer',
#   'Leanne',
#   'Way',
#   'Too',
#   'Scary',
#   'Vocabulary',
#   'I',
#   'excited',
#   'find',
#   'product',
#   'appeared',
#   'fun',
#   'hilarious',
#   'family',
#   'friendly',
#   'way',
#   'expand',
#   'children',
#   'vocabulary',
#   '.',
#   'I',
#   'started',
#   'playing',
#   'car',
#   'son',
#   'daughter',
#   '.',
#   'The',
#   'words',
#   'difficult',
#   'material',
#   'CD',
#   'got',
#   'embarrassing',
#   'seemed',
#   'every',
#   'word',
#   'related',
#   'author',
#   'dating',
#   'sex',
#   'life',
#   'sex',
#   'general',
#   '.',
#   'My',
#   'kids',
#   'said',
#   'remembered',
#   'stories',
#   'words',
#   '.',
#   'After',
#   'going',
#   'first',
#   'CD',
#   'I',
#   'ready',
#   'quit',
#   'even',
#   'kids',
#   'agreed',
#   'poems',
#   'remembering',
#   'devices',
#   'totally',
#   'inappropriate',
#   '.',
#   'I',
#   'got',
#   'anxious',
#   'new',
#   'word',
#   'introduced',
#   'fear',
#   'salacious',
#   'content',
#   'censor',
#   '.',
#   'I',
#   'listened',
#   'little',
#   'kids',
#   'thank',
#   'goodness',
#   'I',
#   'quit',
#   'I',
#   'started',
#   'talking',
#   'date',
#   'high',
#   'school',
#   'getting',
#   'amorous',
#   'guy',
#   'loaded',
#   'drugs',
#   'beach',
#   '!',
#   'I',
#   'guess',
#   'I',
#   'm',
#   'like',
#   'kids',
#   'I',
#   'remember',
#   'word',
#   'trying',
#   'teach',
#   'us',
#   'I',
#   'sure',
#   'remember',
#   'story',
#   '.',
#   'When',
#   'reviewer',
#   'wrote',
#   'challenge',
#   'author',
#   'Ms',
#   '.',
#   'Mazur',
#   'replied',
#   'doesn',
#   'think',
#   'content',
#   'worse',
#   'television',
#   'well',
#   'right',
#   'television',
#   'whole',
#   'lot',
#   'different',
#   'I',
#   'Love',
#   'Lucy',
#   '.',
#   'I',
#   'would',
#   'even',
#   'use',
#   'older',
#   'child',
#   'high',
#   'school',
#   'trashy',
#   '.',
#   'Instead',
#   'listening',
#   'CD',
#   'I',
#   'm',
#   'going',
#   'continue',
#   'read',
#   'good',
#   'literature',
#   'kids',
#   'aloud',
#   '.',
#   'As',
#   'person',
#   'never',
#   'wastes',
#   'anything',
#   'kills',
#   'I',
#   'm',
#   'throwing',
#   'CD',
#   'away',
#   'good',
#   'enough',
#   'give',
#   'Salvation',
#   'Army',
#   '.'],
#  ['This',
#   'product',
#   'marketed',
#   'prep',
#   'graduate',
#   'school',
#   'tests',
#   '.',
#   'I',
#   'bought',
#   'set',
#   'study',
#   'GRE',
#   'found',
#   'I',
#   'could',
#   'use',
#   'study',
#   'aid',
#   'ten',
#   'minutes',
#   'Mazer',
#   'voice',
#   'anecdotes',
#   'proved',
#   'irritating',
#   'seemed',
#   'condescending',
#   '.',
#   'These',
#   'CDs',
#   'may',
#   'helpful',
#   'enjoyable',
#   'young',
#   'high',
#   'school',
#   'students',
#   'studying',
#   'SAT',
#   'ACT',
#   'adults',
#   'college',
#   'students',
#   'stay',
#   'away',
#   '!'],
#  ['I',
#   'wish',
#   'I',
#   'I',
#   'preparing',
#   'SATs',
#   '!',
#   'Renee',
#   'Mazer',
#   'clever',
#   'poems',
#   'catchy',
#   'often',
#   'hilarious',
#   'easy',
#   'remember',
#   '.',
#   'I',
#   'think',
#   'created',
#   'brilliant',
#   'opening',
#   'doors',
#   'whole',
#   'new',
#   'technique',
#   'studying',
#   '.',
#   'Forget',
#   'boring',
#   'SAT',
#   'prep',
#   'classes',
#   'take',
#   '.',
#   'Just',
#   'pick',
#   'CDs',
#   'watch',
#   'score',
#   'go',
#   '!',
#   'Highly',
#   'recommended',
#   '.'],
#  ['When',
#   'ordering',
#   'product',
#   'I',
#   'thought',
#   'would',
#   'interactive',
#   'sound',
#   'track',
#   'annoying',
#   'voice',
#   '.',
#   'I',
#   'worked',
#   'CD',
#   'computer',
#   'audio',
#   'visual',
#   'opportunity',
#   'test',
#   'tests',
#   'offered',
#   'CD',
#   '.',
#   'I',
#   'would',
#   'recommend',
#   'product',
#   'unless',
#   'format',
#   'changed',
#   'offer',
#   'student',
#   'interactive',
#   'experience',
#   '.'],
#  ['Anyone',
#   'voice',
#   'annoying',
#   'woman',
#   'girl',
#   '?',
#   '?',
#   '?',
#   '?',
#   'produce',
#   'audio',
#   'book',
#   '.',
#   '.',
#   '.',
#   '.',
#   'Its',
#   'impossible',
#   'learn',
#   'distracted',
#   'persons',
#   'voice',
#   '.',
#   '.',
#   '.',
#   'buyer',
#   'beware'],
#  ['I',
#   'contemporary',
#   'Christian',
#   'music',
#   'ministry',
#   'years',
#   '.',
#   'I',
#   'deeply',
#   'genre',
#   'recorded',
#   'music',
#   'Twila',
#   'Paris',
#   'Rebecca',
#   'St',
#   '.',
#   'James',
#   'Micheal',
#   'Smith',
#   'Integrity',
#   'Hillsong',
#   'everything',
#   '.',
#   'I',
#   've',
#   'heard',
#   'played',
#   'sang',
#   '.',
#   'I',
#   'never',
#   'found',
#   'single',
#   'album',
#   'songs',
#   'moving',
#   'Danielle',
#   'Rose',
#   '.',
#   'One',
#   'next',
#   'reveal',
#   'faith',
#   'understanding',
#   'deep',
#   '.',
#   'She',
#   'special',
#   '.',
#   '.',
#   '!',
#   'The',
#   'song',
#   'If',
#   'I',
#   'touch',
#   'one',
#   'moving',
#   'songs',
#   'I',
#   'ever',
#   'heard',
#   '.',
#   '.',
#   '!',
#   'You',
#   'Me',
#   'speaks',
#   'Matthew',
#   'clearly',
#   '.',
#   'Litany',
#   'Humility',
#   'sums',
#   'prayer',
#   'holiness',
#   'perfectly',
#   '.',
#   '.',
#   '.',
#   'Mother',
#   'Teresa',
#   'profound',
#   'influence',
#   '.',
#   'The',
#   'title',
#   'song',
#   'CD',
#   'I',
#   'Thirst',
#   'speaks',
#   'Christ',
#   'thirst',
#   'souls',
#   'driving',
#   'motivation',
#   'Mother',
#   'Teresa',
#   'sainted',
#   'life',
#   '.',
#   'I',
#   'read',
#   'Danielle',
#   'entered',
#   'convent',
#   'begin',
#   'consecrated',
#   'life',
#   'nun',
#   '.',
#   'I',
#   'hope',
#   'pray',
#   'continues',
#   'write',
#   'record',
#   'sharing',
#   'mission',
#   'us',
#   'many',
#   'years',
#   'come',
#   '.',
#   '.',
#   'May',
#   'God',
#   'bless',
#   'ministry',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['I',
#   'ordered',
#   'several',
#   'Sheryl',
#   'new',
#   'book',
#   '.',
#   'I',
#   'watched',
#   'gestation',
#   'book',
#   'I',
#   'contributed',
#   'book',
#   'I',
#   'recommend',
#   'highly',
#   'I',
#   'know',
#   'gems',
#   'contains',
#   '.',
#   'If',
#   'ready',
#   'heart',
#   'opened',
#   'let',
#   'overflow',
#   'love',
#   'book',
#   'perfect',
#   'gift',
#   'send',
#   'someone',
#   'else',
#   'time',
#   'holidays',
#   '.',
#   'Let',
#   'hearts',
#   'opened',
#   '.',
#   'You',
#   'may',
#   'change',
#   'sticker',
#   'says',
#   'Do',
#   'open',
#   'Christmas',
#   'say',
#   'Do',
#   'wait',
#   'Christmas',
#   '.',
#   'Enjoy',
#   '.'],
#  ['This',
#   'CD',
#   'ages',
#   '.',
#   'The',
#   'stories',
#   'reason',
#   'story',
#   'simply',
#   'explained',
#   '.',
#   'The',
#   'myths',
#   'grand',
#   'adventures',
#   'filled',
#   'life',
#   'lessons',
#   '.',
#   'I',
#   'listened',
#   'CD',
#   'freeway',
#   'rush',
#   'hour',
#   'mind',
#   'sitting',
#   'bumper',
#   'bumper',
#   '.',
#   'The',
#   'first',
#   'story',
#   'regarding',
#   'Midas',
#   'sets',
#   'pace',
#   '.',
#   'Not',
#   'story',
#   'told',
#   'captivating',
#   'manner',
#   'moral',
#   'story',
#   'explained',
#   'end',
#   '.',
#   'Also',
#   'much',
#   'appreciated',
#   'referral',
#   'library',
#   '!',
#   'Be',
#   'aware',
#   'stories',
#   'addicting',
#   '.'],
#  ['A',
#   'medium',
#   'witted',
#   'piece',
#   'containing',
#   'jokes',
#   'conservative',
#   'politics',
#   'bible',
#   '.',
#   'As',
#   'fun',
#   'dentistry',
#   'share',
#   'relationship',
#   'living',
#   'Christ',
#   '.',
#   'Non',
#   'Christians',
#   'walk',
#   'away',
#   'laughs',
#   'none',
#   'wiser',
#   '.'],
#  ['This',
#   'completely',
#   'fake',
#   '.',
#   'I',
#   'audio',
#   'engineer',
#   'I',
#   'Intrigued',
#   'promotional',
#   'video',
#   'I',
#   'saw',
#   'Facebook',
#   'CD',
#   '.',
#   'The',
#   'claim',
#   'crickets',
#   'singing',
#   'melody',
#   '.',
#   'We',
#   'played',
#   'recording',
#   'crickets',
#   'slowed',
#   'version',
#   '.',
#   'I',
#   'took',
#   'original',
#   'slowed',
#   'make',
#   'comparison',
#   '.',
#   'Guess',
#   '?',
#   'There',
#   'melody',
#   'original',
#   '.',
#   'I',
#   'objection',
#   'making',
#   'melodies',
#   'recordings',
#   'crickets',
#   'thats',
#   'interesting',
#   'thing',
#   '.',
#   'Claiming',
#   'god',
#   'given',
#   'natural',
#   'phenomenon',
#   'however',
#   'complete',
#   'nonsense',
#   'designed',
#   'trick',
#   'people',
#   'buying',
#   'something',
#   '.',
#   'Dont',
#   'fooled',
#   '!'],
#  ['Beautiful', '!', '!'],
#  ['It', 'sublime', 'peaceful', 'wonderful', '.'],
#  ['Dumbfounded', 'Gid', 'His', 'handiwork', '.'],
#  ['Hoax',
#   '.',
#   'You',
#   'tuber',
#   'recreated',
#   'doesn',
#   'sound',
#   'like',
#   'music',
#   '.',
#   'http',
#   'youtu',
#   '.',
#   'qnMmYejDIZ'],
#  ['I', 'hope', 'lot', 'better', '.', 'Would', 'recommend', '.'],
#  ['Too',
#   'short',
#   'music',
#   'much',
#   'paid',
#   '.',
#   'We',
#   'disappointed',
#   'didn',
#   'least',
#   'loop',
#   'music',
#   'something',
#   '?'],
#  ['Thankyou',
#   'I',
#   'really',
#   'enjoyed',
#   'found',
#   'remarkable',
#   '.',
#   'Will',
#   'recommend',
#   'others',
#   '.',
#   'Hope',
#   'find',
#   'comments',
#   'helpful',
#   '.'],
#  ['If',
#   'purports',
#   'would',
#   'cricket',
#   'choirs',
#   'touring',
#   'country',
#   'selling',
#   'concert',
#   'halls',
#   'everywhere',
#   '.'],
#  ['The',
#   'reason',
#   'many',
#   'people',
#   'think',
#   'remarkable',
#   'represented',
#   'natural',
#   'phenomenon',
#   'recording',
#   'crickets',
#   'simply',
#   'slowed',
#   'time',
#   'stretched',
#   'reveal',
#   'really',
#   'sounds',
#   'like',
#   'relative',
#   'lifespan',
#   'cricket',
#   '.',
#   'That',
#   'NOT',
#   'recording',
#   '.',
#   'The',
#   'melody',
#   'seemingly',
#   'emerges',
#   'angelic',
#   'harmonies',
#   'fabrication',
#   'recording',
#   'engineer',
#   'similar',
#   'could',
#   'get',
#   'toy',
#   'sampling',
#   'keyboard',
#   '.',
#   'If',
#   'doubt',
#   'listen',
#   'recording',
#   'actual',
#   'crickets',
#   'provided',
#   'another',
#   'reviewer',
#   'TrumpilyBumpily',
#   'posted',
#   'November',
#   '.',
#   'Or',
#   'record',
#   'crickets',
#   'slow',
#   'recording',
#   '.',
#   'Which',
#   'I',
#   '.',
#   'The',
#   'result',
#   'interesting',
#   'musical',
#   'circular',
#   'saw',
#   '.',
#   'After',
#   'physical',
#   'mechanism',
#   'similar',
#   'cricket',
#   'sings',
#   'rubbing',
#   'ridge',
#   'comblike',
#   'teeth',
#   'along',
#   'edge',
#   'wing',
#   '.',
#   'Granted',
#   'beautiful',
#   'recording',
#   'may',
#   'sort',
#   'feels',
#   'uplifted',
#   'saccharine',
#   'sweetness',
#   '.',
#   'But',
#   'shame',
#   'grossly',
#   'misrepresented',
#   'actual',
#   'recording',
#   'crickets',
#   'quite',
#   'remarkable',
#   'enough',
#   'hold',
#   'thinking',
#   'intelligent',
#   'person',
#   'interest',
#   '.',
#   'If',
#   'purchased',
#   'recording',
#   'thinking',
#   'going',
#   'hear',
#   'remarkable',
#   'revelation',
#   'natural',
#   'world',
#   'misled',
#   '.',
#   'I',
#   'll',
#   'leave',
#   'readers',
#   'listeners',
#   'decide',
#   'whether',
#   'misrepresentation',
#   'deliberate',
#   '.'],
#  ['In',
#   'original',
#   'recording',
#   'Twisted',
#   'Hair',
#   'Robbie',
#   'Robertson',
#   'hear',
#   'SOME',
#   'cricket',
#   'noises',
#   '.',
#   'But',
#   'music',
#   'slowed',
#   'crickets',
#   'See',
#   '.',
#   '.',
#   '.',
#   'This',
#   'clearly',
#   'mix',
#   'cricket',
#   'noises',
#   'slowed',
#   'varying',
#   'degrees',
#   'human',
#   'singers',
#   'musicians',
#   '.',
#   'I',
#   'know',
#   'Mr',
#   '.',
#   'Wilson',
#   'others',
#   'representing',
#   'something',
#   'else',
#   '.',
#   'Personally',
#   'I',
#   'find',
#   'crickets',
#   'track',
#   'distracting',
#   '.',
#   'I',
#   'recommend',
#   'original',
#   'Robbie',
#   'Robertson',
#   'recording',
#   '.'],
#  ['HOAX',
#   '!',
#   'It',
#   'wonderful',
#   'sounding',
#   'record',
#   'sadly',
#   'definite',
#   'hoax',
#   '.',
#   'It',
#   'doesn',
#   'say',
#   'much',
#   'sound',
#   'slowed',
#   'chirps',
#   'cannot',
#   'ever',
#   'sound',
#   'like',
#   'boys',
#   'choir',
#   'played',
#   'CD',
#   '.',
#   'Bear',
#   '.',
#   'Speed',
#   'I',
#   'found',
#   'two',
#   'references',
#   'online',
#   'one',
#   'said',
#   'x',
#   'slower',
#   'point',
#   'd',
#   'still',
#   'hear',
#   'chirpiness',
#   'individual',
#   'beats',
#   'within',
#   'chirp',
#   'gaps',
#   'chirps',
#   'albeit',
#   'everything',
#   'almost',
#   'inaudibly',
#   'low',
#   'frequency',
#   '.',
#   'The',
#   'reference',
#   'said',
#   'proportional',
#   'human',
#   'cricket',
#   'life',
#   'months',
#   'years',
#   'would',
#   'x',
#   'slower',
#   '.',
#   'At',
#   'point',
#   'second',
#   'gap',
#   'conservative',
#   'estimate',
#   'chirps',
#   'would',
#   'become',
#   'second',
#   'gap',
#   'silence',
#   'every',
#   'minute',
#   'three',
#   'minutes',
#   'second',
#   'second',
#   'chirps',
#   '.',
#   'At',
#   'point',
#   'chirp',
#   'well',
#   'audible',
#   'max',
#   'frequency',
#   'say',
#   'Hz',
#   'would',
#   'become',
#   'Hz',
#   'humans',
#   'hear',
#   'Hz',
#   '.',
#   'To',
#   'make',
#   'good',
#   'slowed',
#   'audio',
#   'standard',
#   'CD',
#   'sampling',
#   'rate',
#   'samples',
#   'second',
#   'used',
#   'CDs',
#   'standard',
#   'CD',
#   'equivalent',
#   'quality',
#   'MP',
#   'need',
#   'equipment',
#   'handle',
#   '.',
#   'million',
#   'samples',
#   'per',
#   'second',
#   '.',
#   'Without',
#   'equipment',
#   'get',
#   'stretch',
#   'artifact',
#   'computer',
#   'programs',
#   'nothing',
#   'much',
#   'original',
#   'sound',
#   'recording',
#   '.',
#   'still',
#   'second',
#   'longer',
#   'gaps',
#   'silence',
#   'would',
#   '.',
#   'And',
#   'single',
#   'chirp',
#   'really',
#   'sound',
#   'like',
#   'slow',
#   'x',
#   '?',
#   'You',
#   'hear',
#   'individual',
#   'beats',
#   'within',
#   'chirp',
#   '.',
#   'It',
#   'still',
#   'sounds',
#   'like',
#   'super',
#   'low',
#   'frequency',
#   'chirping',
#   'single',
#   'prominent',
#   'frequency',
#   'within',
#   'beat',
#   'go',
#   'controls',
#   'click',
#   'change',
#   'display',
#   'see',
#   'frequency',
#   'amplitudes',
#   'see',
#   'bold',
#   'unceasing',
#   'frequency',
#   'within',
#   'chirp',
#   '.',
#   'NPR',
#   'reported',
#   'crickets',
#   'others',
#   'beats',
#   'within',
#   'chirp',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['Jim',
#   'Wilson',
#   'didn',
#   'write',
#   '.',
#   'He',
#   'stolen',
#   'song',
#   'Robbie',
#   'Robertson',
#   '.',
#   'The',
#   'choir',
#   'slowed',
#   'crickets',
#   'opera',
#   'singer',
#   'Bonnie',
#   'Jo',
#   'Hunt',
#   '.',
#   'Here',
#   'original',
#   'track',
#   'last',
#   'song',
#   'album',
#   'Music',
#   'For',
#   'Native',
#   'Americans',
#   'called',
#   'Twisted',
#   'Hair',
#   '.',
#   'This',
#   'infringement',
#   'copyright',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['Not',
#   'one',
#   'I',
#   'wanted',
#   '.',
#   'I',
#   'didn',
#   'want',
#   'first',
#   'track',
#   '.',
#   'The',
#   'nd',
#   'background',
#   'live',
#   'cricket',
#   'sound',
#   'loud',
#   '.',
#   'I',
#   'finally',
#   'found',
#   'original',
#   'cd',
#   'Raven',
#   '.',
#   'God',
#   'Cricket',
#   'Chorus',
#   '.',
#   'Order',
#   'magnitude',
#   'better',
#   '.'],
#  ['I', 'believe', 'Show', 'Mercy', 'tracks', '.', 'Thumbs', '!'],
#  ['Great'],
#  ['I',
#   'm',
#   'sure',
#   'came',
#   'ridiculous',
#   'track',
#   'listing',
#   'set',
#   '.',
#   '.',
#   '.',
#   'DDAMN',
#   'SS',
#   '?',
#   'Really',
#   '?',
#   'Pretty',
#   'sad',
#   'omissions',
#   '.',
#   'New',
#   'Slayer',
#   'fans',
#   'Start',
#   'Reign',
#   'Blood',
#   'buy',
#   'entire',
#   'catalog',
#   '.',
#   'This',
#   'waste',
#   '.'],
#  ['Very',
#   'Good',
#   'Very',
#   'Helpful',
#   '!',
#   '!',
#   '!',
#   'Joyce',
#   'Always',
#   'Has',
#   'An',
#   'Anointed',
#   'Helpful',
#   'Word',
#   'Say',
#   '!',
#   '!',
#   '!',
#   'I',
#   'Love',
#   'All',
#   '!',
#   '!',
#   'Joyce',
#   'CD',
#   'Books',
#   'DVDs',
#   '!',
#   '!',
#   '!'],
#  ['This',
#   'got',
#   'best',
#   'GVB',
#   '.',
#   'The',
#   'tight',
#   'rich',
#   'harmonies',
#   'send',
#   'chills',
#   'spine',
#   '.',
#   'He',
#   'Will',
#   'Carry',
#   'You',
#   'America',
#   'I',
#   'Like',
#   'Teach',
#   'World',
#   'wonderful',
#   'mix',
#   'songs',
#   'lift',
#   'spirit',
#   '.'],
#  ['Having',
#   'listened',
#   'groupe',
#   'lot',
#   'I',
#   'thought',
#   'would',
#   'lot',
#   'base',
#   'action',
#   '.',
#   'It',
#   'entirely',
#   'I',
#   'expected',
#   'still',
#   'I',
#   'like',
#   'lot',
#   '.',
#   'I',
#   'really',
#   'love',
#   'Low',
#   'Down',
#   'Chariot',
#   'Gentle',
#   'Shepard',
#   '.',
#   'I',
#   'would',
#   'recomend',
#   '.'],
#  ['There',
#   'absolutely',
#   'question',
#   'guys',
#   'sing',
#   '.',
#   'But',
#   'scream',
#   'lyrics',
#   'nearly',
#   'every',
#   'song',
#   '.',
#   'I',
#   'really',
#   'gotten',
#   'cappella',
#   'lately',
#   'looking',
#   'forward',
#   'CD',
#   '.',
#   'I',
#   'disappointed',
#   '.',
#   'It',
#   'would',
#   'excellent',
#   'wasn',
#   'darn',
#   'loud',
#   '.',
#   'This',
#   'one',
#   'CD',
#   'I',
#   'pass',
#   'someone',
#   'else',
#   '.'],
#  ['This',
#   'cd',
#   'far',
#   'greatest',
#   'ever',
#   'produced',
#   'Gaither',
#   'Vocal',
#   'Band',
#   '.',
#   'Bill',
#   'Guy',
#   'David',
#   'Russ',
#   'shown',
#   'effort',
#   'tremendously',
#   'talented',
#   'versatile',
#   'style',
#   'music',
#   '.',
#   'The',
#   'Gospel',
#   'World',
#   'honored',
#   'claim',
#   'talent',
#   '.',
#   'I',
#   'GVB',
#   'fan',
#   'way',
#   'back',
#   'heard',
#   'lot',
#   'music',
#   'cd',
#   'choice',
#   'songs',
#   'arrangement',
#   'song',
#   'blend',
#   'voices',
#   'touching',
#   '!',
#   'I',
#   'listen',
#   '.',
#   'It',
#   'truly',
#   'God',
#   'inspired',
#   'work',
#   '.',
#   'My',
#   'life',
#   'spiritually',
#   'enhanced',
#   'cd',
#   '.',
#   'I',
#   'hope',
#   'continue',
#   'produce',
#   'works',
#   '.',
#   'My',
#   'prayers',
#   '.'],
#  ['This', 'CD', 'inspirational', 'beautiful', '.'],
#  ['Disc', 'load', 'CD', 'player', '!'],
#  ['two',
#   'disc',
#   'one',
#   'said',
#   '.',
#   'good',
#   'music',
#   '.',
#   '.',
#   '.',
#   'tim',
#   'reed'],
#  ['Classic',
#   '!',
#   'I',
#   'stop',
#   'praising',
#   'His',
#   'name',
#   'car',
#   '.',
#   'Grew',
#   'Don',
#   'Moen',
#   'Ron',
#   'Kenoly',
#   '.',
#   'They',
#   'never',
#   'grow',
#   'old',
#   '.'],
#  ['Poor',
#   'quality',
#   'DVD',
#   'dificult',
#   'listen',
#   'since',
#   'get',
#   'one',
#   'song',
#   'time',
#   'reset',
#   'every',
#   'four',
#   'songs',
#   '.'],
#  ['I',
#   'love',
#   'Don',
#   'Moen',
#   'singing',
#   'I',
#   'never',
#   'heard',
#   'song',
#   'song',
#   'I',
#   'like',
#   '.',
#   'I',
#   'listen',
#   'God',
#   'Will',
#   'Make',
#   'Away',
#   'almost',
#   'daily',
#   'uplifting',
#   'inspired',
#   '.'],
#  ['It',
#   'cd',
#   'second',
#   'one',
#   'didn',
#   'work',
#   'totally',
#   'blank',
#   'music',
#   'st',
#   'one',
#   'fine'],
#  ['This',
#   'best',
#   'worship',
#   'Music',
#   'CD',
#   'I',
#   'ever',
#   'listented',
#   '.',
#   'It',
#   'blessing',
#   'spiritual',
#   'walk',
#   'God',
#   '.',
#   'I',
#   'recommend',
#   'anyone',
#   'wants',
#   'worship',
#   'glorify',
#   'God',
#   'continue',
#   'closer',
#   'walk',
#   'Lord',
#   'Jesus',
#   '!'],
#  ['The',
#   'music',
#   'beautiful',
#   'joyful',
#   '!',
#   'It',
#   'brings',
#   'one',
#   'presence',
#   'God',
#   '.',
#   'Its',
#   'great',
#   'one',
#   'stressed',
#   'upset',
#   'sad',
#   'confused',
#   'fills',
#   'one',
#   'peace',
#   'courage',
#   'strength',
#   'hope',
#   'joy',
#   '!',
#   'I',
#   'highly',
#   'recommend',
#   '!'],
#  ['Don',
#   'Moen',
#   'gift',
#   'worship',
#   'leader',
#   'evident',
#   'cd',
#   'dvd',
#   '.',
#   'He',
#   'brings',
#   'hearer',
#   'along',
#   'celebrates',
#   'praises',
#   'acknowledges',
#   'God',
#   'He',
#   '.',
#   'The',
#   'songs',
#   'quiet',
#   'praise',
#   'welcome',
#   '.',
#   'You',
#   'blessed',
#   'worship',
#   '.',
#   'It',
#   'meant',
#   'performance',
#   '.'],
#  ['I',
#   'playing',
#   'Don',
#   'Moen',
#   'CD',
#   'car',
#   'every',
#   'day',
#   'since',
#   'I',
#   'received',
#   '.',
#   'He',
#   'gifted',
#   'musician',
#   'profound',
#   'love',
#   'God',
#   'shines',
#   'every',
#   'single',
#   'song',
#   '.',
#   'I',
#   'sing',
#   'along',
#   'worship',
#   'along',
#   'blesses',
#   'tremendously',
#   '.',
#   'It',
#   'timeless',
#   'never',
#   'fails',
#   'bring',
#   'presence',
#   'God',
#   '.'],
#  ['song', 'makes', 'think', 'life', '.', 'Love', 'voice', 'good', 'share'],
#  ['A',
#   'great',
#   'hymn',
#   'It',
#   'wonderful',
#   'song',
#   '.',
#   'It',
#   'brought',
#   'tears',
#   'eyes',
#   'would',
#   'appropriate',
#   'subdued',
#   'chuch',
#   'setting',
#   '.',
#   'I',
#   'love',
#   '.'],
#  ['This',
#   'CD',
#   'wonderful',
#   'old',
#   'hymns',
#   '.',
#   'This',
#   'older',
#   'CD',
#   'new',
#   '.',
#   'I',
#   'discovering',
#   'Chris',
#   'Rice',
#   'really',
#   'great',
#   'artist',
#   '.',
#   'He',
#   'great',
#   'voice',
#   'master',
#   'piano',
#   'guitar',
#   '.'],
#  ['came',
#   'perfect',
#   'conditon',
#   'fast',
#   'I',
#   'love',
#   'CD',
#   '!',
#   'I',
#   'think',
#   'I',
#   'order',
#   'another',
#   'one',
#   '.',
#   '.',
#   '.',
#   '.',
#   'good',
#   '!'],
#  ['Love',
#   'Chris',
#   'Rice',
#   'music',
#   '!',
#   'Got',
#   'time',
#   'wonderful',
#   'CD',
#   '!'],
#  ['Gift'],
#  ['The', 'best', 'modern', 'soothing', 'touch', 'classic', 'hymns', '.'],
#  ['The',
#   'music',
#   'great',
#   '!',
#   'Unfortunately',
#   'several',
#   'arrived',
#   'cracked',
#   'cases',
#   '.',
#   'Too',
#   'bad',
#   'I',
#   'bought',
#   'use',
#   'gifts',
#   '.'],
#  ['Love', 'CD', 'brings', 'peace', 'heart', 'soul'],
#  ['I',
#   'REALLY',
#   'ENJOY',
#   'simple',
#   'yet',
#   'lovely',
#   'singing',
#   'hymns',
#   'EXTREMELY',
#   'TALENTED',
#   'singer',
#   'piano',
#   'accompaniment',
#   '.',
#   'My',
#   'whole',
#   'family',
#   'enjoys',
#   'music',
#   'lovely',
#   'indeed',
#   '!',
#   'You',
#   'disappointed',
#   '!',
#   '!',
#   '!',
#   'Listen',
#   'several',
#   'samples',
#   'judge',
#   '!',
#   'It',
#   'SO',
#   'WONDERFUL',
#   'Amazon',
#   'provides',
#   'samples',
#   '!'],
#  ['Gorgeous',
#   'hymns',
#   'done',
#   'beautifully',
#   'wonderful',
#   'singer',
#   '.',
#   'I',
#   'ask',
#   '.'],
#  ['This', 'sooooo', 'calming', '!'],
#  ['soothing',
#   'anthems',
#   '.',
#   'This',
#   'yoga',
#   'lowers',
#   'blood',
#   'pressure',
#   'listening',
#   '.',
#   'He',
#   'gifted',
#   '.'],
#  ['Excellent',
#   'beginning',
#   'end',
#   '.',
#   'Could',
#   'ask',
#   '.',
#   'I',
#   'love',
#   'CD',
#   'came',
#   'well',
#   'packaged',
#   '.',
#   'Could',
#   'wait',
#   'play',
#   '.'],
#  ['I',
#   'like',
#   'mellow',
#   'music',
#   '.',
#   'Music',
#   'compete',
#   'noise',
#   'life',
#   '.',
#   'Music',
#   'soothes',
#   'anxious',
#   'soul',
#   '.',
#   'This',
#   'CD',
#   'suits',
#   'perfectly',
#   '.'],
#  ['So',
#   'repetitious',
#   'makes',
#   'want',
#   'scream',
#   '.',
#   '.',
#   '.',
#   'said',
#   'guy',
#   'could',
#   'perform',
#   '?',
#   'Lousy',
#   'lousy',
#   'lousy'],
#  ['This',
#   'album',
#   'good',
#   '.',
#   'It',
#   'gives',
#   'honor',
#   'Him',
#   'helps',
#   'reflect',
#   'Him',
#   'whenever',
#   'I',
#   'listen',
#   'car',
#   'time',
#   '.',
#   'It',
#   'easy',
#   'get',
#   'caught',
#   'noises',
#   'busyness',
#   'life',
#   'hard',
#   'reflect',
#   'meditate',
#   'God',
#   'need',
#   '.',
#   'Regardless',
#   'style',
#   'music',
#   'different',
#   'people',
#   'like',
#   'I',
#   'would',
#   'imagine',
#   'anyone',
#   'would',
#   'love',
#   'appreciate',
#   'one',
#   'timeless',
#   'breaks',
#   'age',
#   'barriers',
#   '.',
#   'Thank',
#   'Chris',
#   'inspiring',
#   'album',
#   'reminds',
#   'us',
#   'gift',
#   'given',
#   '.',
#   'I',
#   'would',
#   'love',
#   'would',
#   'hymn',
#   'albums',
#   'similar',
#   'one',
#   '.',
#   'I',
#   'give',
#   'album',
#   'gift',
#   'future',
#   '.',
#   'Again',
#   'thank',
#   '!',
#   'W',
#   'Washington'],
#  ['This',
#   'CD',
#   'appear',
#   'available',
#   'UK',
#   'yet',
#   'I',
#   'picked',
#   'Logos',
#   'ship',
#   'heard',
#   'Short',
#   'Term',
#   'Memories',
#   '.',
#   'My',
#   'dad',
#   'liked',
#   'I',
#   'gave',
#   'bought',
#   'another',
#   'one',
#   '.',
#   'I',
#   'also',
#   'picked',
#   'Amusing',
#   'What',
#   'Heart',
#   'Beating',
#   'For',
#   'time',
#   'CD',
#   'stands',
#   '.',
#   'It',
#   'collection',
#   'beautiful',
#   'renditions',
#   'truly',
#   'great',
#   'hymns',
#   'timeless',
#   'melodies',
#   '.',
#   'They',
#   'performed',
#   'minimal',
#   'fuss',
#   'simply',
#   'backed',
#   'piano',
#   'keyboard',
#   'guitar',
#   'smooth',
#   'vocal',
#   'harmonies',
#   'finish',
#   '.',
#   'These',
#   'songs',
#   'demonstrate',
#   'good',
#   'voice',
#   'Chris',
#   'reminding',
#   'occasions',
#   'Daniel',
#   'Bedingfield',
#   '.',
#   'The',
#   'lyrics',
#   'unmodernised',
#   '?',
#   'I',
#   'may',
#   'completely',
#   'grasp',
#   'meaning',
#   'raising',
#   'Ebenezer',
#   'bulwark',
#   'never',
#   'failing',
#   'I',
#   'still',
#   'find',
#   'songs',
#   'uplifting',
#   'particularly',
#   'one',
#   'favourite',
#   'hymns',
#   'It',
#   'well',
#   'soul',
#   '.',
#   'All',
#   'highly',
#   'recommended',
#   '.'],
#  ['Real',
#   'great',
#   'cd',
#   'friends',
#   'love',
#   'true',
#   'blessing',
#   'give',
#   'heart',
#   'got',
#   'God',
#   'try'],
#  ['Beautiful', 'music', 'hardly', 'hear', 'lyrics', 'I', 'bought', '.'],
#  ['I',
#   'loyal',
#   'JMT',
#   'fan',
#   'years',
#   '.',
#   'A',
#   'small',
#   'amount',
#   'time',
#   'considering',
#   'long',
#   'Music',
#   'Business',
#   '.',
#   'And',
#   'I',
#   'collected',
#   'studio',
#   'albums',
#   'conceived',
#   'plus',
#   'years',
#   '.',
#   'From',
#   'Mason',
#   'Proffit',
#   'Years',
#   'rubbing',
#   'shoulders',
#   'likes',
#   'Janis',
#   'Joplin',
#   'many',
#   'great',
#   'singers',
#   'bands',
#   'late',
#   'early',
#   '.',
#   'JMT',
#   'far',
#   'roots',
#   '.',
#   'You',
#   'find',
#   'collection',
#   'mere',
#   'drop',
#   'bucket',
#   'compared',
#   'complete',
#   'library',
#   'likely',
#   'everyone',
#   'reading',
#   'find',
#   'owning',
#   'complete',
#   'library',
#   '.',
#   'But',
#   'great',
#   'start',
#   '.',
#   'This',
#   'I',
#   'think',
#   'perfect',
#   'start',
#   '!',
#   'It',
#   'My',
#   'personal',
#   'Favorite',
#   'songs',
#   'like',
#   '.',
#   '.',
#   '.',
#   'Lilies',
#   'Field',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   'Healer',
#   'Soul',
#   '.',
#   '.',
#   '.',
#   '.',
#   'Hiding',
#   'Place',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   'The',
#   'Pleiades',
#   'Oriion',
#   '.',
#   '.',
#   '.',
#   'Sunrise',
#   '.',
#   'I',
#   'Catholic',
#   'I',
#   'believe',
#   'JMT',
#   'directing',
#   'efforts',
#   'strickly',
#   'toward',
#   'one',
#   'denomination',
#   '.',
#   'This',
#   'music',
#   'celebration',
#   'Jesus',
#   'Christ',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   'sooths',
#   'spririt',
#   'allows',
#   'life',
#   'slow',
#   'realise',
#   'much',
#   'different',
#   'music',
#   'Spirit',
#   'take',
#   '.',
#   'You',
#   'find',
#   'music',
#   'touch',
#   'Brilliance',
#   'song',
#   '.',
#   'His',
#   'Guitar',
#   'picking',
#   'something',
#   'awed',
#   '.',
#   'The',
#   'String',
#   'arrangements',
#   'heard',
#   'many',
#   'songs',
#   'full',
#   'breathtaking',
#   'sensative',
#   'heart',
#   '.',
#   'His',
#   'Voice',
#   'something',
#   'I',
#   'imagine',
#   'God',
#   'Himself',
#   'enjoying',
#   'Heaven',
#   '.',
#   'Above',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   'I',
#   'cannot',
#   'get',
#   'enough',
#   'John',
#   'Micheal',
#   'Talbot',
#   'look',
#   'foward',
#   'new',
#   'release',
#   '.'],
#  ['This',
#   'CD',
#   'openned',
#   'door',
#   'J',
#   '.',
#   'M',
#   '.',
#   'Talbot',
#   'music',
#   'wisdom',
#   '.',
#   'I',
#   'really',
#   'glad',
#   'I',
#   'bought',
#   '.'],
#  ['Beautiful',
#   'songs',
#   'CDs',
#   'started',
#   'skipping',
#   'right',
#   'case',
#   'soothing',
#   'lullaby',
#   '!',
#   'Wasted',
#   'money',
#   '.'],
#  ['Casting',
#   'Crowns',
#   'awesome',
#   'group',
#   '!',
#   '!',
#   '!',
#   'I',
#   'always',
#   'pleased',
#   'music',
#   '.'],
#  ['Wonderful', '!'],
#  ['awesoem'],
#  ['love'],
#  ['awesome', 'album', '!'],
#  ['This',
#   'CD',
#   'became',
#   'stuck',
#   'six',
#   'CD',
#   'changer',
#   'van',
#   'I',
#   'quickly',
#   'tried',
#   'get',
#   'song',
#   'another',
#   'Casting',
#   'Crowns',
#   'album',
#   'son',
#   'loudly',
#   'requesting',
#   '.',
#   'It',
#   'took',
#   'several',
#   'months',
#   'get',
#   'around',
#   'fixing',
#   'CD',
#   'player',
#   'partly',
#   'I',
#   'really',
#   'didn',
#   'mind',
#   'CD',
#   'I',
#   'could',
#   'listen',
#   'driving',
#   '.',
#   'I',
#   'love',
#   'much',
#   '.',
#   'Amazingly',
#   'never',
#   'groans',
#   'family',
#   'member',
#   'listen',
#   'van',
#   'time',
#   '.'],
#  ['Love', 'album', '!'],
#  ['Mark',
#   'gang',
#   'shown',
#   'world',
#   'bless',
#   'Lord',
#   'show',
#   'His',
#   'love',
#   '.',
#   'Awesome',
#   'album',
#   '.',
#   'Must',
#   'hear',
#   'believe',
#   '.'],
#  ['This',
#   'album',
#   'awesome',
#   '.',
#   'I',
#   'love',
#   'Casting',
#   'Crowns',
#   'messages',
#   '.',
#   'As',
#   'youth',
#   'ministry',
#   'partner',
#   'I',
#   'love',
#   'lyrics',
#   'really',
#   'speak',
#   'students',
#   'well',
#   '.'],
#  ['Casting',
#   'Crowns',
#   'recorded',
#   'fantastic',
#   'CD',
#   '.',
#   'Each',
#   'trak',
#   'unique',
#   'message',
#   'appeals',
#   'everyone',
#   'touches',
#   'even',
#   'hardest',
#   'hearts',
#   '.'],
#  ['I',
#   'really',
#   'looking',
#   'forward',
#   'getting',
#   'cd',
#   'definitely',
#   'wasn',
#   'I',
#   'expecting',
#   '.',
#   'There',
#   'couple',
#   'great',
#   'songs',
#   'lyrics',
#   'lack',
#   'substance',
#   'seeming',
#   'try',
#   'tell',
#   'imparting',
#   'wisdom',
#   '.',
#   'Definitely',
#   'music',
#   'driven',
#   'NOT',
#   'lyric',
#   'driven',
#   '.',
#   'Having',
#   'said',
#   'music',
#   'good',
#   'I',
#   'bought',
#   'tunes',
#   '.',
#   'If',
#   'deep',
#   'discount',
#   'bargain',
#   'bin',
#   'I',
#   'might',
#   'buy',
#   'probably',
#   '.',
#   'Peace',
#   '.',
#   'mary'],
#  ['This',
#   'latest',
#   'effort',
#   'Casting',
#   'Crowns',
#   'outstanding',
#   'project',
#   '.',
#   'As',
#   'albums',
#   'lyrically',
#   'powerful',
#   'great',
#   'sound',
#   '.',
#   'There',
#   'several',
#   'good',
#   'songs',
#   'album',
#   '.',
#   'The',
#   'album',
#   'theme',
#   'challenging',
#   'Christians',
#   'live',
#   'faith',
#   'time',
#   'Sunday',
#   'mornings',
#   '.',
#   'There',
#   'couple',
#   'praise',
#   'songs',
#   'prayer',
#   'song',
#   'included',
#   'also',
#   'tracks',
#   'message',
#   'hard',
#   'hitting',
#   'believers',
#   '.',
#   'As',
#   'previous',
#   'albums',
#   'I',
#   'think',
#   'one',
#   'produce',
#   'several',
#   'hit',
#   'singles',
#   '.',
#   'East',
#   'To',
#   'West',
#   'already',
#   'category',
#   '.',
#   'Others',
#   'good',
#   'include',
#   'What',
#   'The',
#   'World',
#   'Needs',
#   'Every',
#   'Man',
#   'Slow',
#   'Fade',
#   '.',
#   'I',
#   'would',
#   'highly',
#   'recommend',
#   'anyone',
#   'already',
#   'fan',
#   'Casting',
#   'Crowns',
#   '.',
#   'For',
#   'unfamiliar',
#   'music',
#   'I',
#   'would',
#   'recommend',
#   'starting',
#   'self',
#   'titled',
#   'debut',
#   '.',
#   'In',
#   'case',
#   'well',
#   'worth',
#   'buying',
#   '.'],
#  ['Casting',
#   'Crowns',
#   'one',
#   'best',
#   'Christians',
#   'artists',
#   '.',
#   'This',
#   'awesome',
#   'CD',
#   '!'],
#  ['I',
#   'gotten',
#   'ripped',
#   'previously',
#   'Casting',
#   'Crowns',
#   'reviews',
#   'I',
#   'gave',
#   'stars',
#   'instead',
#   '.',
#   '.',
#   '.',
#   'doubt',
#   'people',
#   'go',
#   'crazy',
#   'review',
#   '.',
#   'But',
#   'said',
#   'CD',
#   'wasn',
#   'good',
#   '.',
#   'Once',
#   'Casting',
#   'Crowns',
#   'best',
#   'write',
#   'songs',
#   'pointing',
#   'finger',
#   'church',
#   '.',
#   'Yes',
#   'good',
#   'song',
#   'If',
#   'We',
#   'Are',
#   'The',
#   'Body',
#   'Does',
#   'Anybody',
#   'Hear',
#   'Her',
#   'What',
#   'This',
#   'World',
#   'Needs',
#   'gotten',
#   'old',
#   '.',
#   'It',
#   'starts',
#   'become',
#   'annoying',
#   'band',
#   'harps',
#   'one',
#   'point',
#   'especially',
#   'one',
#   'generalizing',
#   'saying',
#   'church',
#   'isn',
#   'supposed',
#   '.',
#   'Move',
#   'another',
#   'topic',
#   '!',
#   '!',
#   '!',
#   'This',
#   'CD',
#   'also',
#   'lacks',
#   'catchiness',
#   'last',
#   'albums',
#   '.',
#   'And',
#   'last',
#   'CD',
#   'solid',
#   'songs',
#   'album',
#   '.',
#   'I',
#   'couldn',
#   'get',
#   'songs',
#   '.',
#   'Musically',
#   'average',
#   'lyrics',
#   'par',
#   '.',
#   'Looking',
#   'forward',
#   'new',
#   'David',
#   'Crowder',
#   'Band',
#   'album',
#   'though',
#   'surely',
#   'disappoint',
#   '.',
#   'Hope',
#   'Casting',
#   'Crowns',
#   'pulls',
#   'together',
#   'next',
#   'album',
#   '.',
#   'This',
#   'one',
#   'sell',
#   'lot',
#   'units',
#   'stand',
#   'test',
#   'time',
#   '.',
#   'It',
#   'collect',
#   'dust',
#   'shelf',
#   '.'],
#  ['I',
#   'bought',
#   'husband',
#   '.',
#   'He',
#   'loves',
#   '.',
#   'Thank',
#   'thank',
#   'great',
#   'shipping',
#   'time',
#   '.',
#   'I',
#   'received',
#   'item',
#   'two',
#   'days',
#   'day',
#   'I',
#   'purchased',
#   '.'],
#  ['I', 'bought', 'CD', 'one', 'song'],
#  ['Loved', 'cd', 'love', 'Guy', '!'],
#  ['I', 'bought', 'gift', '.', 'I', 'order', 'copies', 'got', 'one', '.'],
#  ['I',
#   'love',
#   'singing',
#   'especially',
#   'love',
#   'song',
#   '.',
#   'I',
#   'watch',
#   'Bill',
#   'Gaither',
#   'singing',
#   'shows',
#   'love',
#   'songs',
#   '.'],
#  ['love',
#   'great',
#   'condition',
#   '.',
#   'Guy',
#   'Penrod',
#   'best',
#   'CD',
#   'best',
#   '.',
#   'Thank'],
#  ['Has',
#   'several',
#   'favorite',
#   'songs',
#   'CD',
#   '.',
#   'One',
#   'particular',
#   'really',
#   'helped',
#   'I',
#   'battling',
#   'personal',
#   'grief',
#   '.'],
#  ['A',
#   'previous',
#   'reviewer',
#   'wrote',
#   'Well',
#   'worth',
#   'Gaither',
#   'fans',
#   'young',
#   'old',
#   '!',
#   'Old',
#   '.',
#   'No',
#   'young',
#   'people',
#   'listen',
#   '.',
#   'This',
#   'music',
#   'simply',
#   'awful',
#   '.',
#   'The',
#   'lyrics',
#   'simplistic',
#   'sappy',
#   'melodies',
#   'better',
#   'd',
#   'hear',
#   'advertising',
#   'jingle',
#   '.',
#   'And',
#   'Penrod',
#   'voice',
#   'noting',
#   'write',
#   'home',
#   '.',
#   'Good',
#   'great',
#   '.',
#   'And',
#   'yet',
#   '.',
#   '.',
#   '.',
#   'There',
#   'something',
#   'compelling',
#   'man',
#   '.',
#   'Is',
#   'glorious',
#   'mane',
#   'hair',
#   '?',
#   'The',
#   'trapped',
#   'eighties',
#   'reality',
#   'world',
#   '?',
#   'The',
#   'fact',
#   'legions',
#   'big',
#   'haired',
#   'women',
#   'swoon',
#   'mention',
#   'Penrod',
#   'name',
#   'phallic',
#   'overtones',
#   '?',
#   'I',
#   'know',
#   '.',
#   'His',
#   'music',
#   'godawful',
#   'like',
#   'musical',
#   'train',
#   'wreck',
#   'yet',
#   'I',
#   'look',
#   'away',
#   '.',
#   'It',
#   'almost',
#   'hypnotic',
#   'otherworldly',
#   'weirdness',
#   '.',
#   'To',
#   'really',
#   'get',
#   'full',
#   'effect',
#   'need',
#   'see',
#   'videos',
#   'concert',
#   '.',
#   'Check',
#   'people',
#   'audiences',
#   '.',
#   'All',
#   'women',
#   'Markie',
#   'Post',
#   'hairdo',
#   'Night',
#   'Court',
#   'men',
#   'perms',
#   '.',
#   'And',
#   'one',
#   'looks',
#   'like',
#   'despite',
#   'best',
#   'efforts',
#   '.',
#   'And',
#   'guy',
#   'SUPERSTAR',
#   '.',
#   'You',
#   'simply',
#   'see',
#   'believe',
#   '.'],
#  ['usually',
#   'like',
#   'Guy',
#   'Penrods',
#   'work',
#   'Cd',
#   'doesn',
#   'anything',
#   'image',
#   '.',
#   'I',
#   'found',
#   'lacking',
#   'listening',
#   'times',
#   'put',
#   'retired',
#   'file'],
#  ['If',
#   'like',
#   'Guy',
#   'Penrod',
#   'voice',
#   'uplifting',
#   'worship',
#   'music',
#   'style',
#   'Bill',
#   'Gaither',
#   'enjoy',
#   'CD',
#   '.',
#   'There',
#   'one',
#   'two',
#   'songs',
#   'I',
#   'skip',
#   '.'],
#  ['Still', 'best', 'ever'],
#  ['I',
#   'loved',
#   'watching',
#   '.',
#   'Loved',
#   'learning',
#   'lives',
#   'ministry',
#   '.',
#   'Amazing',
#   'voices',
#   '!'],
#  ['Though',
#   'I',
#   'tend',
#   'agree',
#   'first',
#   'reviewer',
#   'Gaither',
#   'face',
#   'time',
#   'still',
#   'wonderful',
#   'tribute',
#   'George',
#   '.',
#   'He',
#   'Glen',
#   'tops',
#   'great',
#   'hear',
#   'wonderful',
#   'voices',
#   '.',
#   'I',
#   'recommend',
#   'anything',
#   'includes',
#   'George',
#   'Younce',
#   'Glen',
#   'Payne',
#   '.'],
#  ['disk',
#   'scratched',
#   'good',
#   'know',
#   'complain',
#   'VERY',
#   'UNHAPPY',
#   'MY',
#   'MONEY',
#   'WAS',
#   'WAISTED',
#   'VARY',
#   'DIS',
#   'PLEASED',
#   '.',
#   'AND',
#   'WILL',
#   'LET',
#   'EVERY',
#   'ONE',
#   'KNOW',
#   'IS',
#   'NOT',
#   'CORRECTED',
#   'OLLIE',
#   'NEED',
#   'THE',
#   'MONEY',
#   'I',
#   'WAISTED',
#   'BACK'],
#  ['I',
#   'love',
#   'Elvis',
#   'many',
#   'songs',
#   'I',
#   'never',
#   'heard',
#   'I',
#   'mid',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['Elvis', 'still', 'best', '!'],
#  ['All', 'Good'],
#  ['Elvis', 'voice', 'audible', '.', 'Overshadowed', 'music', '.'],
#  ['DVD', 'welded', 'plastic', 'box', '.'],
#  ['I',
#   'fooled',
#   'advertised',
#   'wording',
#   '.',
#   'It',
#   'Elvis',
#   '.',
#   'It',
#   'music',
#   'Elvis',
#   '.',
#   'I',
#   'disappointed',
#   '.'],
#  ['Awesome', 'gospel', 'music'],
#  ['Hymns', 'beautifully', 'sung', 'heart', 'reverence', 'sincerity', '.'],
#  ['It',
#   'copied',
#   'poor',
#   'quality',
#   'master',
#   'bad',
#   'job',
#   'editing',
# ...
#   'Wild',
#   'Animus',
#   'A',
#   'Novel',
#   '.',
#   'He',
#   'must',
#   'lot',
#   'money',
#   'get',
#   'book',
#   'published',
#   'cover',
#   'production',
#   'marketing',
#   'CDs',
#   '.',
#   'I',
#   'm',
#   'sure',
#   'publishing',
#   'company',
#   'would',
#   'ever',
#   'accepted',
#   '.',
#   'I',
#   'suppose',
#   'may',
#   'say',
#   'judge',
#   'art',
#   'grow',
#   '.',
#   'I',
#   'understand',
#   'mean',
#   'I',
#   'feel',
#   'isn',
#   'even',
#   'level',
#   '.',
#   'What',
#   'copy',
#   '?',
#   'I',
#   'tossed',
#   'trash',
#   '.',
#   'First',
#   'time',
#   'I',
#   'ever',
#   '.',
#   'Its',
#   'pungent',
#   'scent',
#   'sting',
#   'nostrils',
#   'lurid',
#   'sounds',
#   'pierced',
#   'eardrums',
#   '.',
#   'Please',
#   'consider',
#   'paying',
#   'money',
#   'unless',
#   've',
#   'listened',
#   'samples',
#   'first',
#   'read',
#   'book',
#   'reviews',
#   '.',
#   'Your',
#   'ears',
#   'quite',
#   'possibly',
#   'thank',
#   '.'],
#  ['The',
#   'prior',
#   'review',
#   'made',
#   'feel',
#   'insulted',
#   'behalf',
#   'Tom',
#   'Waits',
#   'Leonard',
#   'Cohen',
#   'amazing',
#   'lyricists',
#   'though',
#   'I',
#   'completely',
#   'agree',
#   'sentiment',
#   '.',
#   'Not',
#   'surprisingly',
#   'book',
#   'data',
#   'hook',
#   'product',
#   'link',
#   'linked',
#   'class',
#   'link',
#   'normal',
#   'href',
#   'Wild',
#   'Animus',
#   'A',
#   'Novel',
#   'dp',
#   'B',
#   'HWYQX',
#   'ref',
#   'cm',
#   'cr',
#   'arp',
#   'd',
#   'rvw',
#   'txt',
#   '?',
#   'ie',
#   'UTF',
#   'Wild',
#   'Animus',
#   'A',
#   'Novel',
#   'got',
#   'similar',
#   'reactions',
#   'reviews',
#   'way',
#   'I',
#   'felt',
#   'cd',
#   '.',
#   'The',
#   'entire',
#   'thing',
#   'laughable',
#   '.',
#   'When',
#   'painful',
#   'I',
#   'mean',
#   '.',
#   'Funny',
#   'handing',
#   'book',
#   'free',
#   '.'],
#  ['My',
#   'friend',
#   'I',
#   'found',
#   'album',
#   'lounge',
#   '.',
#   'It',
#   'god',
#   'awul',
#   '.',
#   'Rich',
#   'Shapero',
#   'cannot',
#   'sing',
#   '.',
#   'Seriously',
#   '.',
#   'His',
#   'music',
#   'isn',
#   'different',
#   '.',
#   'The',
#   'music',
#   'closely',
#   'resembles',
#   'something',
#   'vein',
#   'Tom',
#   'Waits',
#   'Leonord',
#   'Coen',
#   '.',
#   '.',
#   '.',
#   'If',
#   'lacked',
#   'talent',
#   '.',
#   'Boring',
#   'synth',
#   'mixed',
#   'mediocre',
#   'guitar',
#   'tracks',
#   '.',
#   'The',
#   'singing',
#   'unbearable',
#   'honestly',
#   'laughable',
#   '.',
#   'When',
#   'I',
#   'began',
#   'listening',
#   'I',
#   'idea',
#   'going',
#   'bearable',
#   '.',
#   '.',
#   '.',
#   'vocals',
#   'kicked',
#   'words',
#   'mostly',
#   'incomprehensable',
#   'isn',
#   'ALWAYS',
#   'bad',
#   'case',
#   '.',
#   '.',
#   '.',
#   'lyrics',
#   'could',
#   'heard',
#   'honestly',
#   'laughable',
#   '.',
#   'Shapero',
#   'minimal',
#   'musical',
#   'talent',
#   '.',
#   'On',
#   'top',
#   'singing',
#   'pretty',
#   'bad',
#   'times',
#   'sounds',
#   'totally',
#   'tone',
#   'deaf',
#   '.',
#   'Seriously',
#   'worst',
#   'music',
#   'I',
#   'ever',
#   'heard',
#   '.',
#   'I',
#   'say',
#   'sincerity',
#   'I',
#   'm',
#   'exaggerating',
#   '.'],
#  ['I',
#   'bought',
#   'cd',
#   'song',
#   'One',
#   'Pair',
#   'Hands',
#   'It',
#   'said',
#   'Elvis',
#   'recorded',
#   'song',
#   'however',
#   'Elvis',
#   'Mr',
#   '.',
#   'Robinson',
#   'whole',
#   'CD',
#   'beautiful',
#   'somewhat',
#   'sound',
#   'like',
#   'Elvis',
#   '.'],
#  ['Excellent', 'gets', 'listened', 'almost', 'every', 'day', '.'],
#  ['Carrol', 'Roberson', 'one', 'best', 'singers', '.'],
#  ['I',
#   'highly',
#   'recommend',
#   'anyone',
#   'enjoy',
#   'Gospel',
#   'Music',
#   'Carroll',
#   'wife',
#   'amount',
#   'best',
#   'Gospel',
#   'Music',
#   'Buy',
#   'regret',
#   '!',
#   '!'],
#  ['Carroll',
#   'Roberson',
#   'sings',
#   'like',
#   'gospel',
#   'singer',
#   '.',
#   'His',
#   'whole',
#   'heart',
#   'goes',
#   'every',
#   'word',
#   'makes',
#   'really',
#   'think',
#   '.'],
#  ['Don',
#   'get',
#   'wrong',
#   'Bobby',
#   'Vee',
#   'great',
#   '.',
#   'It',
#   'biggest',
#   'collection',
#   'dreck',
#   'I',
#   'ever',
#   'heard',
#   '.',
#   'Sometimes',
#   'best',
#   'leave',
#   'legacy',
#   'alone',
#   '.',
#   'Out',
#   'tracks',
#   'probably',
#   'less',
#   'handful',
#   'decent',
#   'songs',
#   '.',
#   'Just',
#   'Carole',
#   'King',
#   'name',
#   'associated',
#   'unreleased',
#   'tracks',
#   'doesn',
#   'qualify',
#   '.',
#   'They',
#   'probably',
#   'weren',
#   'released',
#   'good',
#   'reason',
#   '.',
#   'And',
#   'bastardization',
#   'Take',
#   'Good',
#   'Care',
#   'My',
#   'Baby',
#   'truly',
#   'disgusting',
#   '.',
#   'The',
#   'ballad',
#   'version',
#   'originally',
#   'released',
#   'UA',
#   'album',
#   'nice',
#   'alternate',
#   'version',
#   'asks',
#   'question',
#   'happened',
#   'melody',
#   '?',
#   '?',
#   '?',
#   'And',
#   'idea',
#   'produced',
#   'arranged',
#   'anything',
#   'since',
#   'new',
#   'producers',
#   'decided',
#   'lump',
#   'credits',
#   'together',
#   'keeping',
#   'prominent',
#   '.',
#   'Shame',
#   '.',
#   'They',
#   'even',
#   'leave',
#   'first',
#   'names',
#   'writers',
#   'keep',
#   'names',
#   'others',
#   '.',
#   'Makes',
#   'sense',
#   '.',
#   'Most',
#   'songs',
#   'sound',
#   'like',
#   'The',
#   'Night',
#   'Has',
#   'Thousand',
#   'Eyes',
#   'backwards',
#   'sideways',
#   '.',
#   'Save',
#   'money',
#   '.'],
#  ['This',
#   'CD',
#   'set',
#   'contains',
#   'tracks',
#   'many',
#   'released',
#   'first',
#   'time',
#   'others',
#   'found',
#   'limited',
#   'edition',
#   'vinyl',
#   '.',
#   'The',
#   'producer',
#   'Bob',
#   'Celli',
#   'together',
#   'Bobby',
#   'Vee',
#   'family',
#   'done',
#   'absolutely',
#   'exceptional',
#   'job',
#   'remastering',
#   'various',
#   'tracks',
#   'Bobby',
#   'Vee',
#   'never',
#   'sounded',
#   'good',
#   '!',
#   'The',
#   'stereo',
#   'lush',
#   'definition',
#   'superb',
#   '.',
#   'Party',
#   'Doll',
#   'Crickets',
#   'unreleased',
#   'track',
#   'album',
#   'Gone',
#   'apparently',
#   'atrociously',
#   'sounding',
#   'due',
#   'mastering',
#   'problem',
#   'wonderful',
#   '.',
#   'If',
#   'gas',
#   'prices',
#   'top',
#   '.',
#   'economy',
#   'flounders',
#   'need',
#   'trip',
#   'back',
#   'technicolor',
#   'stereo',
#   'must',
#   'set',
#   '.',
#   'One',
#   'issue',
#   'Amazon',
#   'lists',
#   'digital',
#   'download',
#   'addition',
#   'CDs',
#   'info',
#   'package',
#   '.'],
#  ['This',
#   'great',
#   'tribute',
#   'one',
#   'Rock',
#   'And',
#   'Roll',
#   'Teen',
#   'Idols',
#   '.',
#   'A',
#   'lot',
#   'obscure',
#   'unknown',
#   'songs',
#   'brought',
#   'CD',
#   '.',
#   'With',
#   'The',
#   'onset',
#   'Alzheimers',
#   'Bobby',
#   'diagnosed',
#   'sad',
#   'miss',
#   'voice',
#   'double',
#   'CD',
#   'rare',
#   'unreleased',
#   'along',
#   'popular',
#   'CD',
#   'Bobby',
#   'sing',
#   'minds',
#   'hearts',
#   '.'],
#  ['The',
#   'title',
#   'reviews',
#   'classic',
#   'rock',
#   '.',
#   'The',
#   'music',
#   'offered',
#   'classical',
#   'music',
#   '.',
#   'A',
#   'bit',
#   'departure',
#   '.',
#   '.',
#   '.',
#   '.',
#   'After',
#   'reading',
#   'reviews',
#   'I',
#   'ready',
#   'buy',
#   '.',
#   'Will',
#   'look',
#   'elsewhere',
#   '.',
#   'Jeri'],
#  ['Good'],
#  ['Lot', 'remakes', 'I', 'would', 'like'],
#  ['Some',
#   'good',
#   'music',
#   'past',
#   'gets',
#   'light',
#   'current',
#   'radio',
#   'play',
#   'I',
#   'haven',
#   'heard',
#   'Knack',
#   'since',
#   'burned',
#   'brightly',
#   'faded',
#   'quickly',
#   '.',
#   'And',
#   'won',
#   'get',
#   'much',
#   'play',
#   'years',
#   'owning',
#   'set',
#   'affordable',
#   'way',
#   'get',
#   'chart',
#   'quality',
#   'songs',
#   'heard',
#   'much',
#   'today',
#   '.'],
#  ['Wanted', 'music', 'exercise', '.', 'This', 'good', 'album', '.'],
#  ['A',
#   'cross',
#   'section',
#   'great',
#   'songs',
#   'Radio',
#   '.',
#   'A',
#   'must',
#   'top',
#   'greatest',
#   'hits',
#   '.',
#   'Truly',
#   'great',
#   'music',
#   '.',
#   'Peter',
#   'SF'],
#  ['This',
#   'album',
#   'absolutely',
#   'crown',
#   'everything',
#   'good',
#   'rock',
#   'bands',
#   'aspired',
#   'terms',
#   'energy',
#   'attitude',
#   '.',
#   'The',
#   'first',
#   'six',
#   'songs',
#   'Shotgun',
#   'Sally',
#   'Nine',
#   'Lives',
#   'Her',
#   'Monkey',
#   'Whip',
#   'Out',
#   'Long',
#   'Way',
#   'From',
#   'Home',
#   'Coast',
#   'Coast',
#   'top',
#   'notch',
#   'high',
#   'tempo',
#   'face',
#   'ripping',
#   'hard',
#   'rock',
#   'dripping',
#   'raw',
#   'energy',
#   'sleaze',
#   'despite',
#   'ultra',
#   'polished',
#   'production',
#   '.',
#   'The',
#   'album',
#   'one',
#   'eh',
#   'point',
#   'next',
#   'customary',
#   'ballad',
#   'Every',
#   'Sunrise',
#   'steps',
#   'typical',
#   'vomit',
#   'inducing',
#   'dreck',
#   'day',
#   'like',
#   'Warrant',
#   'Heaven',
#   'still',
#   'little',
#   'breathing',
#   'room',
#   'picking',
#   'funkier',
#   'mid',
#   'tempo',
#   'Evil',
#   'Angel',
#   'Bad',
#   'Boys',
#   'Back',
#   'great',
#   'song',
#   'despite',
#   'cringeworthy',
#   'title',
#   'sprinting',
#   'finish',
#   'high',
#   'speed',
#   'closer',
#   'Heaven',
#   'Heartbeat',
#   '.',
#   'Is',
#   'deep',
#   '?',
#   'Of',
#   'course',
#   '.',
#   'But',
#   'want',
#   'push',
#   'envelope',
#   'beyond',
#   'Poison',
#   'Warrant',
#   'like',
#   'without',
#   'going',
#   'full',
#   'metal',
#   'take',
#   'listen',
#   'band',
#   '.',
#   '.',
#   '.',
#   '.',
#   'blame',
#   'speeding',
#   'ticket',
#   '.'],
#  ['Cats',
#   'In',
#   'Boots',
#   'yet',
#   'another',
#   'hard',
#   'rock',
#   'glam',
#   'band',
#   'didn',
#   'enough',
#   'time',
#   'mature',
#   '.',
#   'The',
#   'album',
#   'sleazy',
#   'dripping',
#   'testosterone',
#   'wrapped',
#   'silk',
#   'scarves',
#   'spandex',
#   '.',
#   'Honestly',
#   'another',
#   'Hanoi',
#   'Rocks',
#   'influenced',
#   'band',
#   'wasn',
#   'quite',
#   'yet',
#   '.',
#   'With',
#   'time',
#   'could',
#   '.',
#   'Her',
#   'Monkey',
#   'ok',
#   'song',
#   'along',
#   'Shotgun',
#   'Sally',
#   'pretty',
#   'much',
#   'junk',
#   'glam',
#   'metal',
#   '.',
#   'If',
#   'enjoy',
#   'sleezy',
#   'thin',
#   'rock',
#   'light',
#   'weight',
#   'production',
#   '.',
#   'It',
#   'worst',
#   'album',
#   'genre',
#   'near',
#   'best',
#   'either',
#   '.'],
#  ['years',
#   'album',
#   'released',
#   'CD',
#   '.',
#   'I',
#   'albums',
#   'LP',
#   'hope',
#   'also',
#   'release',
#   'CD'],
#  ['Great',
#   'old',
#   'fashioned',
#   'country',
#   'cowboy',
#   'ballads',
#   '.',
#   'Rich',
#   'warm',
#   'honest',
#   '.',
#   'Wish',
#   'put',
#   'albums',
#   'album',
#   'worth',
#   'price',
#   '.',
#   'I',
#   'hum',
#   'tunes',
#   'day',
#   'long',
#   '.',
#   'Thanks',
#   'Michael',
#   '!'],
#  ['Michael',
#   'Parks',
#   'wonderful',
#   'voice',
#   '.',
#   'This',
#   'CD',
#   'poor',
#   'quality',
#   '.',
#   'Often',
#   'music',
#   'rides',
#   'voice',
#   '.',
#   'I',
#   'original',
#   'LP',
#   'case',
#   'record',
#   '.',
#   'Bought',
#   'gift',
#   'disappointed',
#   '.'],
#  ['nice',
#   'music',
#   '.',
#   'listen',
#   'alot',
#   '.',
#   'would',
#   'buy',
#   'gift',
#   'would',
#   'ecommend',
#   '.',
#   'Love',
#   'hear',
#   'play',
#   'piano',
#   'loving',
#   'singing'],
#  ['It',
#   'nice',
#   'music',
#   'like',
#   'anointed',
#   'Worship',
#   'Music',
#   'I',
#   'hoped',
#   '.'],
#  ['didn', 'like', 'live', 'version'],
#  ['I',
#   'listened',
#   'sample',
#   'recording',
#   'struck',
#   'overwrought',
#   'melodramatic',
#   'Ms',
#   '.',
#   'Crowe',
#   'made',
#   'interpretation',
#   '.',
#   'I',
#   'personally',
#   'cannot',
#   'see',
#   'song',
#   'histrionics',
#   'reflection',
#   'love',
#   'loss',
#   '.',
#   'Mr',
#   '.',
#   'Cohen',
#   'illustrates',
#   'lose',
#   'love',
#   'later',
#   'life',
#   'long',
#   'relationship',
#   'Mr',
#   '.',
#   'Buckley',
#   'interpretation',
#   'young',
#   'man',
#   'lost',
#   'love',
#   'life',
#   'never',
#   'love',
#   'way',
#   '.',
#   'Both',
#   'recordings',
#   'looking',
#   'back',
#   'place',
#   'acceptance',
#   'reflection',
#   '.',
#   'Ms',
#   '.',
#   'Voegele',
#   'recorded',
#   'version',
#   'captures',
#   'feels',
#   'like',
#   'lost',
#   'love',
#   'wounds',
#   'time',
#   'scab',
#   '.',
#   'Like',
#   'Job',
#   'willing',
#   'accept',
#   'suffering',
#   'willing',
#   'curse',
#   'God',
#   'die',
#   '.'],
#  ['Beautiful',
#   'song',
#   'mediocre',
#   'rendition',
#   '.',
#   'The',
#   'Amazon',
#   'preview',
#   'include',
#   'either',
#   'weak',
#   'chat',
#   'beginning',
#   'applause',
#   'end',
#   'either',
#   'OK',
#   'one',
#   'listen',
#   'gets',
#   'old',
#   'quick',
#   '.',
#   'Separate',
#   'taste',
#   'better',
#   'versions',
#   'available',
#   '.',
#   'I',
#   'bought',
#   'wrong',
#   'one',
#   '.'],
#  ['Thank', '.', 'Recommend'],
#  ['Watching',
#   'Ken',
#   'Burns',
#   'film',
#   'Civil',
#   'War',
#   'I',
#   'became',
#   'curious',
#   'music',
#   '.',
#   'Burns',
#   'films',
#   'always',
#   'excellent',
#   'soundtrack',
#   '.',
#   'Anyway',
#   'I',
#   'happy',
#   'discover',
#   'special',
#   'features',
#   'DVD',
#   'interview',
#   'couple',
#   'musicians',
#   '.',
#   '.',
#   '.',
#   'Molly',
#   'Mason',
#   'Jay',
#   'Ungar',
#   '.',
#   'It',
#   'great',
#   'hear',
#   'story',
#   'Ashokan',
#   'Farewell',
#   '.',
#   'What',
#   'beautiful',
#   'heartfelt',
#   'timeless',
#   'piece',
#   '.',
#   'People',
#   'still',
#   'playing',
#   'years',
#   '!'],
#  ['This',
#   'song',
#   'one',
#   'greatest',
#   'songs',
#   'ever',
#   '.',
#   'They',
#   'write',
#   'music',
#   'like',
#   'anymore',
#   '.',
#   'All',
#   'rap',
#   'rock',
#   'music',
#   'dark',
#   'dreary',
#   '.',
#   'truly',
#   'feel',
#   'good',
#   'tune',
#   'simple',
#   'lyrics',
#   '.',
#   'I',
#   'biased',
#   'I',
#   'love',
#   'vibes',
#   'man',
#   'Vince',
#   'Montana',
#   'Jr',
#   '.',
#   'Philly',
#   'sound',
#   '.',
#   'This',
#   'song',
#   'takes',
#   'another',
#   'place',
#   'another',
#   'time',
#   '.',
#   'truly',
#   'beautiful',
#   'music',
#   'live',
#   'forever',
#   'weddings',
#   'many',
#   'places',
#   '.',
#   'I',
#   'love',
#   'sitar',
#   'sounding',
#   'guitar',
#   '.'],
#  ['While',
#   'looking',
#   'songs',
#   'buy',
#   'kindle',
#   'locking',
#   '.',
#   'Punching',
#   'buttons',
#   'madly',
#   'I',
#   'bought',
#   'song',
#   'accident',
#   '.'],
#  ['This',
#   'song',
#   'perfect',
#   'mom',
#   'memorial',
#   'video',
#   '.',
#   'She',
#   'used',
#   'sing',
#   'us',
#   'children',
#   'get',
#   'us',
#   'sleep',
#   '.',
#   'It',
#   'perfect',
#   'version',
#   'sounded',
#   'lot',
#   'like',
#   'voice',
#   '.',
#   'Beautiful',
#   'version',
#   '.'],
#  ['I', 'love', 'song', '!'],
#  ['Beautiful',
#   'song',
#   'nostalgic',
#   'puts',
#   'right',
#   'back',
#   '.',
#   'Very',
#   'easy',
#   'sing',
#   'along',
#   'need',
#   'cheer',
#   'quarrel',
#   'loved',
#   'one',
#   'song',
#   '!'],
#  ['I',
#   'always',
#   'Loved',
#   'song',
#   'Canon',
#   'D',
#   'especially',
#   'Piano',
#   'instrumentals',
#   '.',
#   'So',
#   'I',
#   'knew',
#   'instantly',
#   'song',
#   'I',
#   'wanted',
#   'played',
#   'Wedding',
#   'song',
#   'something',
#   'I',
#   'forever',
#   'remember',
#   'even',
#   'special',
#   'meaning',
#   '.',
#   'I',
#   'hope',
#   'someday',
#   'learn',
#   'play',
#   'piano',
#   '.',
#   'I',
#   'recommend',
#   'song',
#   'anyone',
#   'll',
#   'walking',
#   'aisle',
#   '.'],
#  ['Beautiful',
#   'version',
#   'song',
#   'strings',
#   '.',
#   'I',
#   'used',
#   'one',
#   'songs',
#   'wedding',
#   'ceremony',
#   'processional',
#   '.',
#   'Lovely',
#   'right',
#   'pace',
#   'marching',
#   'aisle',
#   '.'],
#  ['Great', 'tune'],
#  ['Sounded',
#   'better',
#   'I',
#   'heard',
#   'song',
#   'store',
#   'version',
#   'awful',
#   '.',
#   'I',
#   'wish',
#   'I',
#   'hadn',
#   'purchased',
#   '.'],
#  ['song',
#   'bought',
#   'version',
#   'song',
#   'heard',
#   'pandora',
#   '.',
#   'would',
#   'like',
#   'dance',
#   'mix',
#   'add',
#   'party',
#   'library',
#   '.'],
#  ['I',
#   'first',
#   'heard',
#   'Charter',
#   'Music',
#   'Choice',
#   'dance',
#   'channel',
#   '.',
#   'Cool',
#   'dance',
#   'song',
#   'love',
#   'Howard',
#   'Jones',
#   'sample',
#   '.',
#   'On',
#   'dance',
#   'party',
#   'songs',
#   'playlists',
#   '.'],
#  ['Always',
#   'loved',
#   'song',
#   'new',
#   'spin',
#   'Cedric',
#   'Gervais',
#   'makes',
#   'fun',
#   'listen',
#   '!'],
#  ['This',
#   'song',
#   'I',
#   'heard',
#   'golden',
#   'oldie',
#   'I',
#   'first',
#   'listened',
#   'rock',
#   'roll',
#   'early',
#   'sixties',
#   '.',
#   'It',
#   'haunting',
#   'melody',
#   'I',
#   'still',
#   'like',
#   '.',
#   'This',
#   'recording',
#   'stereo',
#   'though',
#   'fidelity',
#   'could',
#   'even',
#   'time',
#   '.',
#   'Said',
#   'released',
#   'probably',
#   'rechanneled',
#   'stereo',
#   'mono',
#   'original',
#   '.',
#   'Contrary',
#   'popular',
#   'myth',
#   'Sleepwalk',
#   'Ultravox',
#   'NOT',
#   'cover',
#   'song',
#   '.',
#   'That',
#   'joke',
#   '.'],
#  ['A',
#   'friend',
#   'husband',
#   'local',
#   'band',
#   'back',
#   'early',
#   'played',
#   'song',
#   'sleepwalk',
#   'I',
#   'love',
#   'ever',
#   'since',
#   '.'],
#  ['New',
#   'copy',
#   'old',
#   'song',
#   'hated',
#   '.',
#   'Will',
#   'delete',
#   'kindle',
#   'soon',
#   'possible'],
#  ['This',
#   'nice',
#   'song',
#   '.',
#   'Well',
#   'performed',
#   'Nancy',
#   'Lee',
#   '.',
#   'It',
#   'one',
#   'favorites',
#   'year',
#   '.',
#   'I',
#   'love',
#   '.',
#   'The',
#   'sound',
#   'good',
#   '.'],
#  ['Great', 'songs', '.', 'Originals', '.', 'No', 're', 'records', '.'],
#  ['I', 'thought', 'I', 'wanted', 'I', 'got', 'sick', 'quickly', '.'],
#  ...]

# %% [markdown]
# ## Lemmatizer

# %%
import nltk
nltk.download("wordnet") 
from nltk.stem import WordNetLemmatizer

# TODO OUGHT TO CHANGE EVERYTHING TO LOWER CASE  !!!!
def lemmatize_token_listlist(token_listlist, reassembleSntcs): 
    wnl = WordNetLemmatizer()
    if reassembleSntcs: 
        lemmatized_tokensentence_list = []
        for tokenlist in token_listlist: lemmatized_tokensentence_list.append(' '.join([wnl.lemmatize(tokens) for tokens in tokenlist]))
        return lemmatized_tokensentence_list
    else: 
        lemmatized_token_listlist = []
        for tokenlist in token_listlist: 
            lemmatized_token_listlist.append([wnl.lemmatize(tokens) for tokens in tokenlist])
    return lemmatized_token_listlist

# %% [markdown]
# # POS-tagger

# %%
# https://www.nltk.org/api/nltk.tag.html
from nltk import pos_tag, word_tokenize
nltk.download('averaged_perceptron_tagger')

#only works for english
def pos_tag_stringlist(strlist, shouldTokenize):
    pos_tagged_strlist = []
    if shouldTokenize: 
        for str in strlist: pos_tagged_strlist.append(pos_tag(word_tokenize(str)))
    else: 
        for str in strlist: pos_tagged_strlist.append(pos_tag(str))
    return pos_tagged_strlist

# %% [markdown]
# # GRID SEARCH

# %%
# need to implement

# %%
# define the two model
### baseline, Hugging Face

# %%
# LOG the results in pandas DataframeŰ

# %%
# STEPS ORDER for Preprocessing
# 1. Basic preprocessing - Should be the first step
# 2. Grammar Correction
# 3. Simplify Contractions
# 4. Lemmatize 
# 5. Remove stop words

# %%
# TODO: 
# 2. Define the technical parameters of the basic NN
## post tagging 
## 10k same sentence 
## first 40 word
## 
#### BASE RNN vs Hugging Face 
# simple pandas dataframe - Columns are preproc methods, 1,0,1, accuracy, etc  
# 4. Best vs Worst Accuracy settings test on bigger corpus # Bigger test, Train? Dev set ?
