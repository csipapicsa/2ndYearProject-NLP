# %%
import pandas as pd
import matplotlib as plt

# %%
# path = "results/results_2022-5-17-13-36-29.csv"
path = "results/1000_words_new_stop_words_results_2022-5-17-13-36-29.csv"
df = pd.read_csv(path)
df.drop(df.columns[0], axis=1, inplace=True)
df.drop(df.columns[-1], axis=1, inplace=True)
df.drop(df.columns[-1], axis=1, inplace=True)
resultcolumns = ["Test Accuracy STOP",'Basic Preprocessing', "Expand Contractions", "Grammar Correction", "Simplify Negotiations", "Lemmatize", "Remove Stop Words_ver2", "Length of Sentence", "Train Accuracy STOP", "Train Loss STOP", "Test Loss STOP"]
res = df[resultcolumns]
res.rename(columns = {'Basic Preprocessing':'BP', 'Expand Contractions':'EC', "Grammar Correction":"GC", "Simplify Negotiations":"SN", "Lemmatize":"Lmtz", "Remove Stop Words_ver2":"StWrd", "Length of Sentence":"Sent.Len", "Train Loss STOP":"Trainloss", "Test Loss STOP":"Testloss", "Train Accuracy STOP":"Train Acc", "Test Accuracy STOP":"Test Acc"}, inplace = True)
res
# Out:
# C:\Users\jasro\anaconda3\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#     Test Acc  BP  EC  GC  SN  Lmtz  StWrd  Sent.Len  Train Acc  Trainloss  \
# 0   0.431673   1   0   1   0     0      1        40      0.236  11.784663
# 1   0.641757   1   1   0   1     0      0        40      0.875   0.279350
# 2   0.431673   1   1   1   1     0      1        40      0.236  11.784690
# 3   0.568127   1   1   1   0     0      1        40      0.762   0.537670
# 4   0.577031   1   1   0   1     0      1        40      0.769   0.530650
# 5   0.578231   1   0   1   1     0      1        40      0.793   0.488759
# 6   0.580332   1   0   0   1     0      1        40      0.796   0.505128
# ...

# %%
df[df["Grammar Correction"]==1]
# Out:
#             Running ID Model Name  Expand Contractions  Basic Preprocessing  \
# 0   2022-5-17-13-36-29        RNN                    0                    1
# 2   2022-5-17-13-36-29        RNN                    1                    1
# 3   2022-5-17-13-36-29        RNN                    1                    1
# 5   2022-5-17-13-36-29        RNN                    0                    1
# 9   2022-5-17-13-36-29        RNN                    0                    1
# 11  2022-5-17-13-36-29        RNN                    1                    1
# 12  2022-5-17-13-36-29        RNN                    1                    1
# 14  2022-5-17-13-36-29        RNN                    0                    1
#
#     Grammar Correction  Simplify Negotiations  Lemmatize  \
# 0                    1                      0          0
# 2                    1                      1          0
# 3                    1                      0          0
# ...
