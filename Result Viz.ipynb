# %%
import pandas as pd
import matplotlib as plt

# %%
# path = "results/results_2022-5-17-13-36-29.csv"
path = "results/RNN/5K_train_maxlen_40_words_results.csv"
df = pd.read_csv(path)
df.drop(df.columns[0], axis=1, inplace=True)
#df.drop(df.columns[-1], axis=1, inplace=True)
#df.drop(df.columns[-1], axis=1, inplace=True)
resultcolumns = ["Expand Contractions", "Basic Preprocessing", "Grammar Correction", 
                 "Simplify Negotiations", "Lemmatize", "Remove Stop Words", "Train Accuracy STOP","Test Accuracy STOP",
                 "Vocabulary Size"]
res = df[resultcolumns]
res.rename(columns = {'Basic Preprocessing':'BP', 
                      'Expand Contractions':'EC', 
                      "Grammar Correction":"GC", 
                      "Simplify Negotiations":"SN", 
                      "Lemmatize":"L", "Remove Stop Words":"RSW",
                      "Length of Sentence":"Sent.Len", 
                      "Train Accuracy STOP":"Train Acc", "Test Accuracy STOP":"Test Acc"}, inplace = True)
res.tail()
# Out:
# c:\users\music\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:5034: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#     EC  BP  GC  SN  L  RSW  Train Acc  Test Acc  Vocabulary Size
# 27   0   1   1   0  0    0     0.9624  0.843237            20874
# 28   0   1   0   1  0    0     0.9542  0.844138            27145
# 29   0   1   0   0  0    0     0.9646  0.844838            27145
# 30   1   1   0   1  1    0     0.8924  0.845538            25681
# 31   1   1   0   0  0    0     0.9596  0.845638            27075

# %%
df[df["Grammar Correction"]==1]
# Out:
#             Running ID Model Name  Expand Contractions  Basic Preprocessing  \
# 0   2022-5-17-13-36-29        RNN                    0                    1
# 2   2022-5-17-13-36-29        RNN                    1                    1
# 3   2022-5-17-13-36-29        RNN                    1                    1
# 5   2022-5-17-13-36-29        RNN                    0                    1
# 9   2022-5-17-13-36-29        RNN                    0                    1
# 11  2022-5-17-13-36-29        RNN                    1                    1
# 12  2022-5-17-13-36-29        RNN                    1                    1
# 14  2022-5-17-13-36-29        RNN                    0                    1
#
#     Grammar Correction  Simplify Negotiations  Lemmatize  \
# 0                    1                      0          0
# 2                    1                      1          0
# 3                    1                      0          0
# ...
